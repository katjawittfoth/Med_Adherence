# %%
from pyspark.sql import SparkSession  
import os                             

from pyspark.sql.types import *

from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.classification import GBTClassifier
from pyspark.ml.classification import LinearSVC
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.classification import OneVsRest
from pyspark.ml.classification import RandomForestClassifier

# %%
def load_from_mongodb(publicIP:str, db:str, collection:str):
    pyspark_submit_args = '--packages org.mongodb.spark:mongo-spark-connector_2.11:2.4.0 pyspark-shell'
    os.environ["PYSPARK_SUBMIT_ARGS"] = pyspark_submit_args
    
    uri = "mongodb://{}/{}.{}".format(publicIP, db, collection)
    
    ss = SparkSession.builder \
                     .appName("myApp") \
                     .config("spark.mongodb.input.uri", uri)\
                     .getOrCreate()
    loaded_data = ss.read.format("com.mongodb.spark.sql.DefaultSource").load()
    return loaded_data

# %%
def labelize(df, labelCol:str):
    """
    Rename the specified column as `label` in the input DataFrame object df.
    """
    if labelCol != 'label':
        return df.withColumnRenamed(existing=labelCol, new='label')

# %%
def binarize_label(df, targetValues:list):
    """
    Label the `targetValues` in the column `label` as 1 in the DataFrame df.
    """
    from pyspark.sql.functions import udf
    
    def label_converter(label):
        if label in targetValues:
            return int(1)
        else: 
            return 0

    label_udf = udf(f=label_converter, returnType=IntegerType())
    
    df_binarized = df.withColumn('numeric_label', label_udf(df['label']))\
                     .drop('label')\
                     .withColumnRenamed('numeric_label', 'label')
    return df_binarized

# %%
def create_train_test_sets(labelizedDF,
                           featureCols:list, splitRatio:list, labelCol="label", seed=None):
    """
    Transform a clean DataFrame with numeric label columns 
    into features and label vectors for modeling.
    Split into training and test set and cache them in the memory.
    """
    # Turn raw columns into features and label vectors
    from pyspark.ml.feature import VectorAssembler
    
    # if label column is not 'label' then change it into 'label'
    labelizedDF = labelizedDF.withColumnRenamed(existing=labelCol, new='label')
    
    va = VectorAssembler(inputCols=featureCols, outputCol='features')
    labeledPoints = va.transform(labelizedDF).select('features', labelCol)
    
    
    
    # Then split into train and test set
    train, test = labeledPoints.randomSplit(splitRatio, seed=seed)
    
    return train.cache(), test.cache()

# %%
def create_evaluators(evalType:str, metrics:list, 
                      labelCol='label', predictionCol='prediction'):
    """
    Initiate either 'bina' (binary) or 'multi' (multiclass) classification evaluators.
    """
    
    if evalType=='multi':
        from pyspark.ml.evaluation import MulticlassClassificationEvaluator
        evaluators = [MulticlassClassificationEvaluator(metricName=metric) for metric in metrics]
        return evaluators
    
    elif evalType=='bina':
        from pyspark.ml.evaluation import BinaryClassificationEvaluator
        evaluators = [BinaryClassificationEvaluator(metricName=metric) for metric in metrics]
        return evaluators
    
    else:
        print('Invalid input.')
        return None

# %%
def modeling(training_data, clf):
    """
    Take a training DataFrame, an estimator, and a performance metric.
    Return the trained model and training time. 
    """
    from time import time
    start_train = time()
    clf_trained = clf.fit(training_data)
    training_time = time() - start_train
    print("Training time in seconds is {}.\n".format(training_time))
    
    return clf_trained, training_time

# %%
def model_evaluate(testing_data, trained_clf, evaluators:list):
    """
    Take a test set, a trained model, and performance metrics for evaluation.
    Return performance metrics and prediction time.
    """
    from time import time
    start_pred = time()
    pred = trained_clf.transform(testing_data)
    pred_time = time() - start_pred
    
    pred.select('label','prediction').groupBy('label','prediction').count().show()
    
    scores = []
    for evaluator in evaluators:
        score = evaluator.evaluate(pred)
        scores.append(score)
        print(f"{evaluator.getMetricName().capitalize()} score = {score}")
        if evaluator.getMetricName() == 'accuracy':
            print(f"Test Error = {1 - score}")
#             scores.append(1-score)
    print(f"\nPredition time in seconds is: {pred_time}")
    return scores, pred_time

# %%
def run_model(clf, training_data, testing_data, evaluators):
    """
    Combine all model fitting and evaluation functions together.
    """
    trained_model, training_time = modeling(training_data=training_set, clf=clf)
    scores, pred_time = model_evaluate(testing_data=testing_set, trained_clf=trained_model, evaluators=evaluators)
    return trained_model, training_time, pred_time, scores

# %% [markdown]
# # Main program

# %%
# main program

# load data from MongoDB
df_raw = load_from_mongodb(publicIP='18.217.205.7', db='sensors', collection='forty')

# rename label column as 'label'
df = labelize(df_raw, 'profile_activity')

# binarize target labels into 1 and 0
targetActions = ['non_dominant_pill_med', 'dominant_pill_med', 'dominant_liquid_med', 'non_dominant_liquid_med']
df = binarize_label(df, targetValues=targetActions)

# create train, test sets
feature_cols = df.drop('_id', 'label').columns
training_set, testing_set = create_train_test_sets(df, featureCols=feature_cols, labelCol='label', 
                                                   seed=1, splitRatio=[0.8, 0.2])


# initiate performance evaluators to compare all models
metrics = ['f1', 'accuracy', 'weightedPrecision', 'weightedRecall']
evaluators = create_evaluators(evalType='multi', metrics=metrics, predictionCol='prediction')

# %% [markdown]
# ## Random Forest with default parameter settings

# %%
rf = RandomForestClassifier(seed = 42)
rf_model, rf_training_time, rf_pred_time, rf_scores = run_model(clf=rf, evaluators=evaluators, 
                                                                training_data=training_set, 
                                                                testing_data=testing_set)
# Out:
# Training time in seconds is 45.502580642700195.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    5|
# |    0|       0.0|   75|
# |    1|       1.0|   85|
# |    0|       1.0|   10|
# +-----+----------+-----+
#
# F1 score = 0.9141453141453142
# Accuracy score = 0.9142857142857143
# Test Error = 0.08571428571428574
# Weightedprecision score = 0.9155075187969925
# Weightedrecall score = 0.9142857142857143
#
# Predition time in seconds is: 0.16902375221252441

# %% [markdown]
# ## Random Forest with tuned hyperparameters

# %%
rf_tune = RandomForestClassifier(maxDepth=30, numTrees=50, seed = 42)

rf_tune_model, rf_tune_training_time, rf_tune_pred_time, rf_tune_scores = run_model(clf=rf_tune, 
                                                                                    evaluators=evaluators, 
                                                                                    training_data=training_set, 
                                                                                    testing_data=testing_set)
# Out:
# Training time in seconds is 14.069912672042847.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    2|
# |    0|       0.0|   83|
# |    1|       1.0|   88|
# |    0|       1.0|    2|
# +-----+----------+-----+
#
# F1 score = 0.9771428571428572
# Accuracy score = 0.9771428571428571
# Test Error = 0.02285714285714291
# Weightedprecision score = 0.9771428571428572
# Weightedrecall score = 0.9771428571428572
#
# Predition time in seconds is: 0.12610292434692383

# %% [markdown]
# ## Random Forest with tuned hyperparameters 2

# %%
rf_tune2 = RandomForestClassifier(maxDepth=30, numTrees=50, featureSubsetStrategy='sqrt', seed = 42)
rf_tune2_model, rf_tune2_training_time, rf_tune2_pred_time, rf_tune2_scores = run_model(clf=rf_tune2, 
                                                                                        evaluators=evaluators, 
                                                                                        training_data=training_set,
                                                                                        testing_data=testing_set)
# Out:
# Training time in seconds is 13.312894105911255.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    2|
# |    0|       0.0|   83|
# |    1|       1.0|   88|
# |    0|       1.0|    2|
# +-----+----------+-----+
#
# F1 score = 0.9771428571428572
# Accuracy score = 0.9771428571428571
# Test Error = 0.02285714285714291
# Weightedprecision score = 0.9771428571428572
# Weightedrecall score = 0.9771428571428572
#
# Predition time in seconds is: 0.13925385475158691

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression(regParam=0.01, maxIter=1000, fitIntercept=True)
lr_model, lr_training_time, lr_pred_time, lr_scores = run_model(clf=lr, evaluators=evaluators, 
                                                                training_data=training_set, 
                                                                testing_data=testing_set)
# Out:
# Training time in seconds is 60.9147207736969.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    7|
# |    0|       0.0|   77|
# |    1|       1.0|   83|
# |    0|       1.0|    8|
# +-----+----------+-----+
#
# F1 score = 0.9142689015192202
# Accuracy score = 0.9142857142857143
# Test Error = 0.08571428571428574
# Weightedprecision score = 0.9143118785975928
# Weightedrecall score = 0.9142857142857144
#
# Predition time in seconds is: 0.12568426132202148

# %% [markdown]
# ## Gradient-Boosted Tree Classifier

# %%
gbt = GBTClassifier(maxIter=50, seed=42)
gbt_model, gbt_training_time, gbt_pred_time, gbt_scores = run_model(clf=gbt, evaluators=evaluators, 
                                                                    training_data=training_set, 
                                                                    testing_data=testing_set)
# Out:
# Training time in seconds is 208.78445649147034.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    2|
# |    0|       0.0|   84|
# |    1|       1.0|   88|
# |    0|       1.0|    1|
# +-----+----------+-----+
#
# F1 score = 0.982859383094608
# Accuracy score = 0.9828571428571429
# Test Error = 0.017142857142857126
# Weightedprecision score = 0.9829258277651274
# Weightedrecall score = 0.9828571428571429
#
# Predition time in seconds is: 0.1262812614440918

# %% [markdown]
# ## Linear Support Vector Machine

# %%
svm = LinearSVC(maxIter=100, regParam=0.1)
svm_model, svm_training_time, svm_pred_time, svm_scores = run_model(clf=svm, evaluators=evaluators, 
                                                                    training_data=training_set, 
                                                                    testing_data=testing_set)
# Out:
# Training time in seconds is 20.61867332458496.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    8|
# |    0|       0.0|   73|
# |    1|       1.0|   82|
# |    0|       1.0|   12|
# +-----+----------+-----+
#
# F1 score = 0.8855795854224351
# Accuracy score = 0.8857142857142857
# Test Error = 0.11428571428571432
# Weightedprecision score = 0.8863747232541559
# Weightedrecall score = 0.8857142857142857
#
# Predition time in seconds is: 0.06303858757019043

# %% [markdown]
# ## OneVsRest

# %%
ovr = OneVsRest(classifier=lr)
ovr_model, ovr_training_time, ovr_pred_time, ovr_scores = run_model(clf=ovr, evaluators=evaluators, 
                                                                    training_data=training_set, 
                                                                    testing_data=testing_set)
# Out:
# Training time in seconds is 117.82324767112732.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    7|
# |    0|       0.0|   77|
# |    1|       1.0|   83|
# |    0|       1.0|    8|
# +-----+----------+-----+
#
# F1 score = 0.9142689015192202
# Accuracy score = 0.9142857142857143
# Test Error = 0.08571428571428574
# Weightedprecision score = 0.9143118785975928
# Weightedrecall score = 0.9142857142857144
#
# Predition time in seconds is: 0.5393030643463135

# %% [markdown]
# # Random Forest with selected features

# %% [markdown]
# After running random forest models, we noticed that not all features help the model. Some features have very low importance that the importance score is returned as 0. We use features with non-zero importance in some algorithms to see if using a more selective set of features helps increases their performance.

# %% [markdown]
# ## Extract important features

# %%
# allFeatures = df.drop('_id','label').columns

features_dict = dict()
for ft_index, ft_name in enumerate(df.columns):
    features_dict[ft_index] = ft_name
# colIndex_to_delete = [colIndex for colIndex, colName in features_dict.items() 
#                       if colName in ['_id', 'label']]
# for colIndex in colIndex_to_delete:
#     del features_dict[colIndex]

# select the features that have non-zero significance
n_features = len(rf_tune_model.featureImportances.indices) 

important_features = []
for impt, feature_index in sorted(zip(rf_tune_model.featureImportances.values, 
                                      rf_tune_model.featureImportances.indices), reverse=True)[:n_features]:
    important_features.append(features_dict[feature_index+1])
    print(f"{features_dict[feature_index+1]} : {impt}")
# Out:
# global_max_z_val_accelerometer : 0.018102714742531036
# global_std_y_val_accelerometer : 0.008470467932173794
# global_95_percentile_z_val_accelerometer : 0.008216018076404718
# global_std_x_val_accelerometer : 0.007398996175978697
# bin19_std_y_val_accelerometer : 0.0069988666407970355
# global_75_percentile_z_val_accelerometer : 0.006887370583319257
# bin8_std_z_val_gyroscope : 0.006645707003685561
# bin18_std_y_val_gyroscope : 0.006339215466729085
# global_min_z_val_accelerometer : 0.006266699455065079
# bin6_max_z_val_accelerometer : 0.006077281220544812
# bin18_std_z_val_gyroscope : 0.005999144359622649
# bin16_std_y_val_accelerometer : 0.005415515487585808
# bin7_75_percentile_z_val_accelerometer : 0.005318877469731636
# global_max_x_val_gyroscope : 0.004717285879776724
# bin17_std_y_val_gyroscope : 0.004627222012141572
# global_std_y_val_gyroscope : 0.0044772667362868454
# global_5_percentile_x_val_gyroscope : 0.004277094525262298
# bin9_95_percentile_z_val_accelerometer : 0.004162615750419789
# bin8_max_z_val_gyroscope : 0.004033748125832
# bin7_95_percentile_z_val_accelerometer : 0.003828110284642326
# bin17_max_z_val_gyroscope : 0.003650478654728913
# global_75_percentile_y_val_gyroscope : 0.0036045739667585537
# global_95_percentile_x_val_gyroscope : 0.003601548832785168
# bin9_75_percentile_z_val_accelerometer : 0.003367335428471518
# global_min_x_val_accelerometer : 0.0033491266182430358
# bin16_max_z_val_accelerometer : 0.0032867795139688515
# bin20_min_y_val_gyroscope : 0.003239823320090259
# bin18_max_z_val_gyroscope : 0.0030398416438040636
# bin9_std_z_val_gyroscope : 0.0030059268459556652
# bin17_std_z_val_gyroscope : 0.0030047021239172004
# bin16_std_y_val_gyroscope : 0.002956834042486594
# global_avg_z_val_accelerometer : 0.0029533586933616768
# bin18_75_percentile_z_val_accelerometer : 0.0029525953169135693
# bin18_95_percentile_z_val_accelerometer : 0.0029395664517532466
# bin18_95_percentile_z_val_gyroscope : 0.002869318717542275
# bin17_avg_z_val_gyroscope : 0.0027856840605972903
# bin6_std_y_val_accelerometer : 0.0027785727699861837
# global_std_x_val_gyroscope : 0.0027529359758142594
# bin3_std_x_val_accelerometer : 0.002750153784231719
# global_5_percentile_y_val_gyroscope : 0.0026725429521931403
# bin8_std_y_val_gyroscope : 0.002645151920612026
# bin7_std_y_val_gyroscope : 0.002644651061391277
# bin20_5_percentile_y_val_gyroscope : 0.0026383774824445677
# bin15_std_x_val_accelerometer : 0.0026265189965403155
# bin13_max_z_val_accelerometer : 0.002625228441870695
# bin12_max_z_val_gyroscope : 0.002603908303824268
# bin18_5_percentile_z_val_accelerometer : 0.0025971560116724033
# bin12_95_percentile_z_val_gyroscope : 0.0025842075225415164
# bin18_avg_y_val_accelerometer : 0.002556075734367062
# bin4_95_percentile_z_val_gyroscope : 0.002511286663956578
# bin37_med_y_val_gyroscope : 0.002510556774269684
# bin6_std_z_val_accelerometer : 0.0024886591855901937
# bin6_std_z_val_gyroscope : 0.0024845423259061738
# bin10_std_y_val_gyroscope : 0.0024633692938554152
# bin19_95_percentile_z_val_accelerometer : 0.002461440781653224
# bin7_std_y_val_accelerometer : 0.0024500582727192653
# bin38_5_percentile_y_val_accelerometer : 0.00238343069813779
# bin5_std_y_val_accelerometer : 0.0023823837524557055
# global_min_y_val_accelerometer : 0.002335036135245923
# bin5_max_z_val_accelerometer : 0.0023037700306949545
# bin13_std_y_val_accelerometer : 0.0022724660588844697
# bin5_med_z_val_accelerometer : 0.002240498956499116
# bin8_75_percentile_z_val_accelerometer : 0.002226387943373296
# bin20_std_y_val_gyroscope : 0.002224367386881099
# bin16_std_z_val_accelerometer : 0.0022225974347337297
# bin34_avg_y_val_gyroscope : 0.0022194480661070462
# bin15_5_percentile_z_val_accelerometer : 0.002210276198548447
# bin5_95_percentile_z_val_gyroscope : 0.002181559408409618
# bin19_avg_z_val_gyroscope : 0.002161579678840842
# bin19_std_z_val_gyroscope : 0.0021614302992702993
# bin15_std_y_val_gyroscope : 0.0021466382555521335
# bin18_min_x_val_gyroscope : 0.002133884527396748
# bin19_med_z_val_accelerometer : 0.0021311352342042625
# bin15_max_z_val_gyroscope : 0.0021301765371041885
# bin39_5_percentile_y_val_accelerometer : 0.002122150228711106
# bin28_min_x_val_gyroscope : 0.002107407070617836
# global_25_percentile_y_val_accelerometer : 0.0020726660416055306
# bin38_max_y_val_accelerometer : 0.0020675607370349274
# bin16_std_z_val_gyroscope : 0.0020578702209073925
# bin39_5_percentile_z_val_gyroscope : 0.002049753697787994
# bin18_avg_z_val_accelerometer : 0.0020423362524586383
# bin17_5_percentile_y_val_accelerometer : 0.002032283794751525
# bin5_max_z_val_gyroscope : 0.0020306709949981937
# bin21_avg_y_val_accelerometer : 0.0020222935431372904
# bin18_95_percentile_y_val_accelerometer : 0.0020147152087251173
# bin14_std_y_val_accelerometer : 0.001999737481785435
# bin15_95_percentile_z_val_gyroscope : 0.001999422540575506
# bin16_std_x_val_accelerometer : 0.0019767568177563974
# bin36_95_percentile_z_val_accelerometer : 0.0019495965846106993
# bin11_std_z_val_gyroscope : 0.0019372184527545126
# bin4_std_y_val_gyroscope : 0.0019304921484545549
# bin27_std_y_val_accelerometer : 0.0019052678526271325
# global_std_z_val_accelerometer : 0.001894352448470377
# bin15_25_percentile_y_val_accelerometer : 0.0018747184568113958
# bin18_min_y_val_gyroscope : 0.0018645014405898562
# bin4_max_z_val_gyroscope : 0.001842974918863365
# bin11_std_x_val_accelerometer : 0.0018178831588167845
# bin8_avg_z_val_gyroscope : 0.0018142423560120855
# bin16_95_percentile_z_val_gyroscope : 0.0017852568246974935
# bin15_std_y_val_accelerometer : 0.0017655737426143208
# bin4_25_percentile_z_val_accelerometer : 0.0017648988040339562
# bin15_25_percentile_y_val_gyroscope : 0.0017560870345094811
# bin7_std_z_val_accelerometer : 0.0017354829569758699
# bin6_avg_z_val_gyroscope : 0.0017327917518160873
# bin18_max_z_val_accelerometer : 0.0017241440294230442
# bin16_min_y_val_gyroscope : 0.0017158635636722152
# bin16_95_percentile_y_val_gyroscope : 0.0017151376895626973
# bin3_std_z_val_accelerometer : 0.0017100371330583768
# bin19_75_percentile_z_val_accelerometer : 0.0017034424616144523
# bin13_med_y_val_gyroscope : 0.0017018714226976486
# bin18_75_percentile_x_val_accelerometer : 0.0016816296208051129
# bin18_std_y_val_accelerometer : 0.001676420913066446
# bin5_5_percentile_z_val_gyroscope : 0.0016684517237726831
# bin18_med_z_val_accelerometer : 0.0016663893413228388
# bin16_avg_y_val_accelerometer : 0.0016579263940493312
# bin4_max_z_val_accelerometer : 0.0016566125190589284
# bin9_95_percentile_z_val_gyroscope : 0.0016369798288532243
# bin6_med_z_val_accelerometer : 0.0016358453347370188
# bin9_min_y_val_gyroscope : 0.0016293841119474142
# bin20_med_x_val_accelerometer : 0.0016290996604729352
# global_75_percentile_x_val_accelerometer : 0.0016259230609183598
# bin36_95_percentile_x_val_accelerometer : 0.001622762748011603
# bin9_std_y_val_gyroscope : 0.0016140903084131857
# bin10_25_percentile_x_val_accelerometer : 0.0016106105212859909
# bin20_min_x_val_accelerometer : 0.0015979188777605754
# bin38_avg_y_val_accelerometer : 0.0015785459109738267
# bin2_std_y_val_accelerometer : 0.0015573031851293918
# global_min_y_val_gyroscope : 0.001543602103325494
# bin17_avg_x_val_accelerometer : 0.00153750495064153
# bin8_25_percentile_z_val_gyroscope : 0.0015276176586650578
# bin8_95_percentile_z_val_accelerometer : 0.001526662293986591
# bin7_std_z_val_gyroscope : 0.0015113336763640608
# bin38_max_y_val_gyroscope : 0.0015105881915957902
# bin25_std_x_val_gyroscope : 0.0015102174928248566
# bin12_std_z_val_accelerometer : 0.001500148387509931
# bin17_std_y_val_accelerometer : 0.0014959188487257593
# bin20_std_x_val_accelerometer : 0.0014916819466916013
# bin29_5_percentile_x_val_accelerometer : 0.001491106040682492
# bin9_avg_z_val_accelerometer : 0.0014745096155988153
# global_95_percentile_y_val_accelerometer : 0.0014722502386712512
# global_25_percentile_z_val_gyroscope : 0.001467816988295961
# bin16_95_percentile_y_val_accelerometer : 0.0014559590814354735
# bin35_med_x_val_gyroscope : 0.0014526499544061477
# bin19_95_percentile_y_val_gyroscope : 0.0014370595143008503
# bin21_min_x_val_accelerometer : 0.0014319875487572055
# bin10_5_percentile_x_val_gyroscope : 0.0014268199856676924
# bin18_med_y_val_accelerometer : 0.0014177891032697426
# bin22_avg_y_val_gyroscope : 0.0014080019260439588
# bin6_5_percentile_x_val_accelerometer : 0.0014058493235731614
# bin20_med_y_val_accelerometer : 0.0013856425191201254
# bin17_min_y_val_gyroscope : 0.0013818926823656553
# bin13_med_z_val_accelerometer : 0.0013806432913841128
# bin11_5_percentile_z_val_accelerometer : 0.0013779615899280025
# bin19_med_y_val_accelerometer : 0.001376335305530688
# bin28_std_x_val_gyroscope : 0.0013705138515493858
# bin19_med_y_val_gyroscope : 0.0013640200976299212
# bin11_std_x_val_gyroscope : 0.001339425434810918
# bin18_med_z_val_gyroscope : 0.0013375726915609526
# bin19_min_y_val_accelerometer : 0.0013330905618176858
# bin17_avg_z_val_accelerometer : 0.001330793813763145
# bin15_med_y_val_gyroscope : 0.0013294494968186744
# bin19_25_percentile_x_val_accelerometer : 0.0013293359270241062
# bin40_25_percentile_x_val_accelerometer : 0.0013285608630264664
# bin3_95_percentile_z_val_gyroscope : 0.0013263619538612817
# bin20_max_x_val_accelerometer : 0.0013255557164850613
# bin21_med_z_val_accelerometer : 0.0013118902302260906
# bin19_5_percentile_y_val_gyroscope : 0.0013108943720099818
# bin12_std_x_val_accelerometer : 0.001305080731185987
# bin18_95_percentile_y_val_gyroscope : 0.0012999470349301869
# bin20_std_y_val_accelerometer : 0.0012971779912103686
# bin7_95_percentile_x_val_accelerometer : 0.0012907628934471908
# bin40_max_z_val_gyroscope : 0.0012897856818635588
# bin22_med_y_val_accelerometer : 0.0012804356598527628
# bin9_5_percentile_y_val_gyroscope : 0.001272357475671439
# bin11_max_z_val_accelerometer : 0.0012716049733357956
# bin21_95_percentile_z_val_accelerometer : 0.0012607963637849041
# bin7_95_percentile_x_val_gyroscope : 0.0012598719056554288
# bin15_95_percentile_z_val_accelerometer : 0.0012588303830886596
# bin10_std_z_val_accelerometer : 0.0012521075341913974
# bin13_5_percentile_y_val_accelerometer : 0.0012429581717909482
# bin7_95_percentile_z_val_gyroscope : 0.0012352603978117594
# bin37_5_percentile_y_val_gyroscope : 0.0012342536907279478
# bin10_25_percentile_x_val_gyroscope : 0.0012241790511353305
# bin17_med_y_val_accelerometer : 0.0012234031301425494
# bin2_med_z_val_gyroscope : 0.0012168338650379144
# bin18_5_percentile_x_val_gyroscope : 0.0012125582608550074
# global_5_percentile_z_val_accelerometer : 0.001208964492336211
# bin38_med_x_val_accelerometer : 0.0012088556570128018
# bin2_med_x_val_gyroscope : 0.0011992414065600978
# bin17_25_percentile_x_val_gyroscope : 0.0011857498945652878
# bin17_75_percentile_z_val_accelerometer : 0.001179530430851919
# bin27_75_percentile_y_val_accelerometer : 0.0011774954642084843
# bin14_75_percentile_z_val_accelerometer : 0.001163764223188024
# bin13_std_z_val_gyroscope : 0.001163747391634334
# bin40_avg_z_val_accelerometer : 0.0011627109295469255
# bin2_max_y_val_gyroscope : 0.0011620380612328103
# bin2_max_x_val_gyroscope : 0.001160590383162779
# bin8_med_z_val_accelerometer : 0.0011568357505565845
# bin26_25_percentile_y_val_gyroscope : 0.0011532466061713797
# bin23_5_percentile_y_val_gyroscope : 0.0011504382710398157
# bin22_med_x_val_gyroscope : 0.0011446947456436325
# bin2_95_percentile_z_val_gyroscope : 0.0011292230820954146
# bin32_min_x_val_accelerometer : 0.0011281020885208692
# bin10_5_percentile_y_val_accelerometer : 0.0011228628614553301
# bin10_min_x_val_gyroscope : 0.0011201374425153959
# bin4_95_percentile_z_val_accelerometer : 0.0011185498288300854
# bin4_std_x_val_gyroscope : 0.0011178092562100905
# global_max_z_val_gyroscope : 0.0011113760267089578
# bin16_avg_z_val_gyroscope : 0.0011108148196027933
# bin2_std_z_val_gyroscope : 0.0011092613541150704
# bin16_std_x_val_gyroscope : 0.0011078039956641842
# bin8_95_percentile_y_val_accelerometer : 0.0011072726667863827
# bin6_avg_z_val_accelerometer : 0.0011002059648533818
# bin40_min_y_val_gyroscope : 0.0010985366198312274
# bin12_5_percentile_x_val_gyroscope : 0.001097436303077515
# bin12_std_z_val_gyroscope : 0.0010961389852611506
# bin17_5_percentile_x_val_accelerometer : 0.0010929833320202508
# global_avg_y_val_gyroscope : 0.0010906558023709742
# global_std_z_val_gyroscope : 0.0010891163081415997
# bin13_25_percentile_x_val_accelerometer : 0.0010861679573323658
# bin40_med_x_val_gyroscope : 0.0010853431231279422
# bin14_75_percentile_x_val_accelerometer : 0.001082348139026489
# bin19_max_z_val_gyroscope : 0.001082060590733257
# bin27_med_y_val_gyroscope : 0.0010817494163765412
# bin16_95_percentile_z_val_accelerometer : 0.0010809376296482616
# bin23_25_percentile_x_val_gyroscope : 0.0010808290005674362
# bin1_95_percentile_y_val_accelerometer : 0.0010742533209825479
# bin39_min_y_val_accelerometer : 0.001072643750204951
# bin6_min_x_val_gyroscope : 0.0010724345878046226
# bin8_75_percentile_z_val_gyroscope : 0.0010613287430867376
# bin12_std_y_val_gyroscope : 0.0010610955824825283
# bin19_25_percentile_y_val_accelerometer : 0.0010561615489618633
# bin36_75_percentile_y_val_gyroscope : 0.0010528969219246174
# bin26_25_percentile_z_val_gyroscope : 0.0010520195431623594
# bin36_25_percentile_z_val_gyroscope : 0.0010518322146523102
# bin13_std_y_val_gyroscope : 0.001050139467400401
# bin8_5_percentile_y_val_gyroscope : 0.0010470965687375993
# bin8_min_z_val_gyroscope : 0.0010364160608653033
# bin1_min_y_val_accelerometer : 0.0010357450428938144
# bin39_max_z_val_gyroscope : 0.0010349608941414895
# bin10_std_y_val_accelerometer : 0.0010270198266693518
# bin17_75_percentile_y_val_gyroscope : 0.0010086865039218983
# bin20_75_percentile_x_val_gyroscope : 0.0010081303180734511
# bin37_25_percentile_y_val_gyroscope : 0.0010065891385211238
# bin2_95_percentile_z_val_accelerometer : 0.0010053623686284733
# bin38_95_percentile_y_val_gyroscope : 0.0010047831519095585
# global_med_x_val_gyroscope : 0.0010040678028086355
# bin25_95_percentile_x_val_accelerometer : 0.0009943607212389688
# bin2_25_percentile_z_val_gyroscope : 0.000993000598210706
# bin14_std_y_val_gyroscope : 0.0009862451729794447
# bin17_std_x_val_gyroscope : 0.0009857626396728345
# bin35_avg_z_val_gyroscope : 0.000983889574928552
# bin40_25_percentile_z_val_gyroscope : 0.0009814737377186686
# bin28_avg_x_val_accelerometer : 0.000980726559346905
# bin40_25_percentile_y_val_accelerometer : 0.0009765557379409275
# bin40_5_percentile_z_val_gyroscope : 0.0009759699629106045
# global_avg_z_val_gyroscope : 0.0009743152194795392
# bin20_max_x_val_gyroscope : 0.0009711316036804976
# bin11_max_z_val_gyroscope : 0.0009702777680021283
# bin40_25_percentile_x_val_gyroscope : 0.0009693113505867237
# bin34_min_x_val_accelerometer : 0.0009664948818750101
# bin14_min_x_val_accelerometer : 0.0009649037516840362
# bin37_95_percentile_y_val_accelerometer : 0.0009628052125261241
# bin7_75_percentile_z_val_gyroscope : 0.0009587044112636851
# bin13_95_percentile_z_val_accelerometer : 0.0009558349115572132
# bin16_max_x_val_gyroscope : 0.0009555408501807109
# bin36_95_percentile_x_val_gyroscope : 0.0009482859575555859
# bin38_max_x_val_gyroscope : 0.0009481282965883125
# bin32_25_percentile_x_val_accelerometer : 0.0009408288042756111
# bin26_avg_x_val_gyroscope : 0.0009392971073634876
# bin24_max_y_val_gyroscope : 0.0009326082148221098
# bin38_25_percentile_z_val_accelerometer : 0.0009320530787457961
# bin20_avg_x_val_gyroscope : 0.0009319660557351221
# bin15_75_percentile_x_val_accelerometer : 0.0009238438615731886
# bin15_min_z_val_accelerometer : 0.0009235158917133509
# global_95_percentile_y_val_gyroscope : 0.0009166226498071627
# bin32_min_z_val_accelerometer : 0.0009159537574640077
# bin17_75_percentile_y_val_accelerometer : 0.0009150478082906182
# bin18_std_x_val_accelerometer : 0.0009124020267850254
# bin21_std_y_val_gyroscope : 0.0009110386288418348
# bin21_min_z_val_accelerometer : 0.0009098205464356168
# bin39_avg_x_val_accelerometer : 0.0009086504346608668
# bin24_std_z_val_accelerometer : 0.0009011348080843138
# bin18_max_x_val_accelerometer : 0.0008983473685386259
# bin39_95_percentile_z_val_gyroscope : 0.0008964451037553478
# bin18_avg_z_val_gyroscope : 0.0008893729321026625
# bin8_avg_z_val_accelerometer : 0.0008846274753996725
# bin24_5_percentile_z_val_accelerometer : 0.0008832610240002357
# bin31_med_y_val_gyroscope : 0.000878464328476363
# bin18_75_percentile_y_val_accelerometer : 0.0008779198183280502
# bin13_5_percentile_z_val_gyroscope : 0.0008756350175803673
# bin40_avg_x_val_accelerometer : 0.0008694391113309207
# bin27_75_percentile_z_val_gyroscope : 0.0008692579705403254
# bin40_95_percentile_z_val_gyroscope : 0.0008684716988717569
# bin34_95_percentile_z_val_accelerometer : 0.0008682994792275143
# bin15_5_percentile_y_val_gyroscope : 0.0008672395900824888
# bin31_5_percentile_y_val_accelerometer : 0.0008658237546515356
# global_95_percentile_z_val_gyroscope : 0.0008622924436050327
# bin21_max_z_val_accelerometer : 0.0008612094710495435
# bin12_25_percentile_z_val_accelerometer : 0.0008601174072731939
# bin35_5_percentile_x_val_accelerometer : 0.0008597169870260498
# bin21_75_percentile_x_val_gyroscope : 0.0008579462857181825
# bin2_95_percentile_x_val_gyroscope : 0.0008577860161022424
# bin32_std_y_val_accelerometer : 0.0008574090747139474
# bin19_std_z_val_accelerometer : 0.0008565802409510638
# bin9_5_percentile_z_val_accelerometer : 0.0008543409829046745
# bin9_25_percentile_x_val_gyroscope : 0.000851881655738452
# bin15_75_percentile_y_val_accelerometer : 0.0008501101614077979
# bin3_75_percentile_z_val_gyroscope : 0.0008463938051971483
# bin39_25_percentile_y_val_gyroscope : 0.0008427325850087079
# bin36_avg_z_val_accelerometer : 0.0008426145412035592
# bin14_avg_z_val_accelerometer : 0.0008416210328338931
# bin38_75_percentile_y_val_accelerometer : 0.000837549424804459
# bin4_avg_x_val_accelerometer : 0.0008359803533112218
# bin15_5_percentile_z_val_gyroscope : 0.0008359383181226523
# bin22_75_percentile_y_val_accelerometer : 0.0008355014215201407
# bin1_max_x_val_gyroscope : 0.0008338382363013809
# bin27_min_x_val_accelerometer : 0.0008272364920926407
# bin3_max_z_val_gyroscope : 0.0008242206601305318
# bin7_std_x_val_accelerometer : 0.0008237369436864295
# bin16_avg_z_val_accelerometer : 0.0008221700170947742
# bin33_max_z_val_gyroscope : 0.0008220886159044912
# bin10_95_percentile_z_val_gyroscope : 0.0008214247894214045
# bin25_avg_x_val_accelerometer : 0.0008150814397411941
# bin37_min_x_val_accelerometer : 0.0008111233106067532
# bin12_std_x_val_gyroscope : 0.0008106976521447096
# bin12_5_percentile_x_val_accelerometer : 0.0008097879160194709
# bin27_std_x_val_accelerometer : 0.0008095333007073452
# bin20_95_percentile_x_val_accelerometer : 0.0008089873264109477
# bin22_5_percentile_z_val_accelerometer : 0.0008070899283323613
# bin10_med_x_val_accelerometer : 0.0008063447130049702
# bin4_5_percentile_z_val_accelerometer : 0.0008063255379696958
# bin16_75_percentile_x_val_accelerometer : 0.0008061102647287069
# bin8_95_percentile_z_val_gyroscope : 0.000805942505612179
# bin28_25_percentile_x_val_gyroscope : 0.0008014818969131913
# bin15_avg_x_val_accelerometer : 0.0007998398559848293
# bin38_std_x_val_accelerometer : 0.0007971309119356409
# bin34_med_z_val_gyroscope : 0.0007945259264987496
# bin26_avg_y_val_accelerometer : 0.0007903420389994569
# bin21_min_x_val_gyroscope : 0.0007893412590009284
# bin19_5_percentile_y_val_accelerometer : 0.0007877887599567268
# bin14_max_z_val_accelerometer : 0.0007877126372140289
# bin10_std_z_val_gyroscope : 0.0007857970583934313
# bin16_avg_y_val_gyroscope : 0.0007812807535095593
# bin25_5_percentile_y_val_gyroscope : 0.0007810258010823986
# bin21_25_percentile_z_val_gyroscope : 0.0007809806011684495
# bin37_max_y_val_accelerometer : 0.0007807596971010128
# bin9_75_percentile_y_val_accelerometer : 0.0007796128417658246
# bin15_max_y_val_gyroscope : 0.000779442388463096
# bin36_25_percentile_y_val_gyroscope : 0.0007782068235367869
# bin8_25_percentile_y_val_accelerometer : 0.0007760183164928191
# bin37_5_percentile_x_val_gyroscope : 0.0007759562600308835
# bin40_min_x_val_accelerometer : 0.0007758929523289424
# bin17_95_percentile_y_val_gyroscope : 0.0007748697058875979
# bin40_med_y_val_gyroscope : 0.0007747451544514157
# bin16_5_percentile_z_val_gyroscope : 0.0007675136733050939
# bin37_75_percentile_x_val_accelerometer : 0.0007667327633777103
# bin24_std_x_val_accelerometer : 0.0007663458357435739
# bin8_med_z_val_gyroscope : 0.0007631150406396951
# bin11_75_percentile_x_val_gyroscope : 0.0007630702835657107
# bin2_5_percentile_z_val_gyroscope : 0.0007595678868192766
# bin38_std_y_val_accelerometer : 0.000759376135011053
# bin5_med_z_val_gyroscope : 0.0007585967748159246
# bin40_avg_z_val_gyroscope : 0.0007585751579660347
# bin38_5_percentile_y_val_gyroscope : 0.0007569234527078426
# bin34_95_percentile_y_val_gyroscope : 0.0007560780156101431
# bin12_max_z_val_accelerometer : 0.0007559022355405635
# bin39_75_percentile_y_val_gyroscope : 0.0007543394658966067
# bin11_min_x_val_gyroscope : 0.0007541210037874006
# bin3_min_y_val_accelerometer : 0.0007538619955501485
# bin31_95_percentile_x_val_gyroscope : 0.0007521351967322452
# bin33_5_percentile_z_val_accelerometer : 0.0007509049280099821
# bin23_med_y_val_accelerometer : 0.0007505960054587745
# bin10_75_percentile_x_val_gyroscope : 0.0007480467506325422
# bin22_std_z_val_gyroscope : 0.0007469313310625637
# bin24_75_percentile_y_val_gyroscope : 0.0007455905436879097
# bin19_avg_y_val_gyroscope : 0.0007448865176626802
# bin37_std_z_val_gyroscope : 0.0007425458339145111
# bin2_75_percentile_x_val_accelerometer : 0.000742380825113265
# bin11_std_y_val_accelerometer : 0.0007421858839728596
# bin18_5_percentile_x_val_accelerometer : 0.0007401171781817795
# bin35_max_y_val_gyroscope : 0.0007395589479840211
# bin23_avg_x_val_accelerometer : 0.0007354730076210641
# bin4_min_x_val_accelerometer : 0.000734552392183738
# bin19_95_percentile_x_val_accelerometer : 0.0007330768177953442
# bin40_std_z_val_gyroscope : 0.0007301598082368921
# bin35_avg_z_val_accelerometer : 0.0007282746619003812
# bin36_5_percentile_z_val_accelerometer : 0.0007243289317333872
# bin24_avg_x_val_gyroscope : 0.000723341771944363
# bin3_25_percentile_y_val_accelerometer : 0.0007231381160139981
# bin28_avg_z_val_accelerometer : 0.0007212540104590084
# bin9_25_percentile_y_val_accelerometer : 0.0007199311321837593
# bin35_95_percentile_z_val_gyroscope : 0.0007190408075037672
# bin22_25_percentile_y_val_gyroscope : 0.0007163916279728962
# bin13_med_x_val_accelerometer : 0.0007162986280344775
# bin21_5_percentile_y_val_gyroscope : 0.0007156852759776557
# bin14_95_percentile_z_val_gyroscope : 0.0007147862486928274
# bin2_max_z_val_accelerometer : 0.0007146517735578293
# bin36_95_percentile_z_val_gyroscope : 0.0007141897181154528
# bin8_std_z_val_accelerometer : 0.000711054353566513
# bin39_med_z_val_gyroscope : 0.0007100716254191174
# bin20_avg_x_val_accelerometer : 0.0007087085218174294
# bin19_std_y_val_gyroscope : 0.0007073844432740142
# bin39_std_z_val_gyroscope : 0.0007070266643355008
# bin10_95_percentile_x_val_gyroscope : 0.0007062609217066072
# bin38_25_percentile_y_val_accelerometer : 0.0007060451970377003
# bin7_max_z_val_accelerometer : 0.0007045588128166597
# bin10_25_percentile_y_val_gyroscope : 0.0007041885968270973
# bin14_95_percentile_y_val_accelerometer : 0.0007035135998053919
# bin14_min_y_val_accelerometer : 0.0007013698192204711
# bin9_med_y_val_gyroscope : 0.0006990424153364533
# bin25_75_percentile_y_val_accelerometer : 0.0006920359562945402
# bin19_min_x_val_accelerometer : 0.0006917158519769747
# bin1_min_y_val_gyroscope : 0.0006866133846202915
# bin11_25_percentile_z_val_gyroscope : 0.0006850249710511711
# bin16_min_x_val_gyroscope : 0.0006848514002810284
# bin5_min_y_val_accelerometer : 0.0006823319837467522
# bin34_25_percentile_y_val_accelerometer : 0.0006802760849114393
# bin2_min_z_val_accelerometer : 0.0006783538453268025
# bin17_max_z_val_accelerometer : 0.0006781869274462822
# bin31_std_z_val_accelerometer : 0.0006759500303044436
# bin28_75_percentile_x_val_gyroscope : 0.0006738522916552836
# bin1_avg_z_val_accelerometer : 0.0006719395236227207
# bin19_min_x_val_gyroscope : 0.0006714875475212323
# bin12_95_percentile_z_val_accelerometer : 0.0006703152685604986
# bin11_avg_z_val_accelerometer : 0.0006691918346859008
# bin23_min_x_val_gyroscope : 0.0006688243047126062
# bin27_max_y_val_gyroscope : 0.0006675706917258968
# bin13_med_z_val_gyroscope : 0.0006669394319546457
# bin8_5_percentile_z_val_gyroscope : 0.0006666053283477113
# bin3_5_percentile_y_val_gyroscope : 0.0006661377050171751
# bin15_med_y_val_accelerometer : 0.0006658423504334441
# bin30_25_percentile_x_val_gyroscope : 0.0006651627541562375
# bin7_avg_x_val_gyroscope : 0.0006644384549385079
# bin21_75_percentile_x_val_accelerometer : 0.0006634994192424828
# bin6_25_percentile_x_val_accelerometer : 0.00066241751667119
# bin17_95_percentile_z_val_gyroscope : 0.0006587936004085127
# bin29_25_percentile_y_val_accelerometer : 0.0006571502777920619
# bin13_25_percentile_z_val_gyroscope : 0.0006566908661425456
# bin23_med_z_val_accelerometer : 0.0006555239641952202
# bin33_max_y_val_gyroscope : 0.0006542221072694926
# bin21_avg_z_val_accelerometer : 0.0006532921177847694
# bin23_avg_y_val_accelerometer : 0.000653226834343968
# bin13_avg_x_val_accelerometer : 0.0006529879337029765
# bin6_75_percentile_z_val_accelerometer : 0.0006525162231549726
# bin21_max_x_val_accelerometer : 0.0006515244829386783
# bin29_5_percentile_x_val_gyroscope : 0.000651243534379507
# bin14_75_percentile_x_val_gyroscope : 0.0006503898758083204
# bin35_min_y_val_gyroscope : 0.0006501657661693253
# bin6_min_z_val_accelerometer : 0.0006490837551501224
# bin3_min_x_val_accelerometer : 0.0006479323598853731
# bin7_med_y_val_gyroscope : 0.0006455451923997318
# bin11_5_percentile_z_val_gyroscope : 0.00064152854210519
# bin4_25_percentile_x_val_accelerometer : 0.0006414248766398132
# bin25_min_z_val_accelerometer : 0.0006408056287749115
# bin12_75_percentile_y_val_gyroscope : 0.0006386361414801457
# bin8_std_x_val_gyroscope : 0.0006384274628679216
# bin17_avg_y_val_accelerometer : 0.0006384040152750049
# bin29_med_x_val_gyroscope : 0.0006369993640073818
# bin32_75_percentile_z_val_gyroscope : 0.0006361195299281544
# bin36_max_z_val_gyroscope : 0.0006346763605455083
# bin8_5_percentile_z_val_accelerometer : 0.0006323881369326759
# bin13_avg_y_val_gyroscope : 0.0006310193847730055
# bin35_max_z_val_accelerometer : 0.0006290728959689614
# bin5_min_z_val_gyroscope : 0.0006285541088690693
# bin33_95_percentile_z_val_gyroscope : 0.0006259448576496959
# bin15_min_z_val_gyroscope : 0.0006259393881375016
# bin34_25_percentile_x_val_accelerometer : 0.0006258860915214111
# bin7_5_percentile_y_val_gyroscope : 0.0006227521374149657
# bin37_med_x_val_accelerometer : 0.0006227206811392039
# bin29_med_z_val_accelerometer : 0.0006200290568605183
# bin30_75_percentile_x_val_accelerometer : 0.0006197565961001292
# bin26_75_percentile_z_val_accelerometer : 0.0006195224907612887
# bin12_75_percentile_z_val_gyroscope : 0.0006193017173598927
# bin32_med_y_val_gyroscope : 0.0006175757479562039
# global_avg_y_val_accelerometer : 0.0006172570536239144
# bin5_min_z_val_accelerometer : 0.000616130602135006
# bin2_max_z_val_gyroscope : 0.0006139933754813568
# bin36_med_z_val_gyroscope : 0.0006125668359689235
# bin39_med_x_val_gyroscope : 0.0006115322418712568
# bin21_med_x_val_accelerometer : 0.0006108634397144894
# bin23_95_percentile_z_val_accelerometer : 0.0006097311880721368
# bin33_med_y_val_gyroscope : 0.0006089995051588418
# bin35_95_percentile_z_val_accelerometer : 0.0006089492534331026
# bin30_75_percentile_x_val_gyroscope : 0.0006071255988614209
# bin7_avg_z_val_gyroscope : 0.0006070551983417664
# bin40_5_percentile_y_val_gyroscope : 0.0006062051595868716
# bin8_5_percentile_x_val_gyroscope : 0.0006059432591418336
# bin26_min_z_val_accelerometer : 0.000605644694335293
# bin32_75_percentile_y_val_gyroscope : 0.0006041102235302223
# bin2_std_y_val_gyroscope : 0.0006026183421194814
# bin8_95_percentile_y_val_gyroscope : 0.0006025948769410211
# bin22_min_y_val_gyroscope : 0.0006019462372056251
# bin2_5_percentile_x_val_accelerometer : 0.00060126043387431
# bin39_avg_z_val_accelerometer : 0.0006012539687228786
# bin21_med_y_val_gyroscope : 0.0006006181284228707
# bin18_5_percentile_z_val_gyroscope : 0.0006001464509780759
# bin20_avg_y_val_accelerometer : 0.0005996440102496424
# bin8_max_y_val_gyroscope : 0.0005993216384665812
# bin2_95_percentile_y_val_accelerometer : 0.0005987887745555132
# bin35_min_z_val_gyroscope : 0.0005986957680320185
# bin35_min_x_val_accelerometer : 0.0005986476327824037
# bin4_min_y_val_accelerometer : 0.0005985770496242241
# bin1_max_y_val_gyroscope : 0.0005965172420286618
# bin35_min_x_val_gyroscope : 0.0005955028286265588
# bin5_avg_z_val_gyroscope : 0.0005945267445108439
# bin20_5_percentile_x_val_gyroscope : 0.0005943024367368201
# bin31_avg_y_val_accelerometer : 0.0005922499213437545
# bin12_avg_y_val_accelerometer : 0.0005908907701251147
# bin19_5_percentile_x_val_accelerometer : 0.0005905864896315074
# bin22_max_z_val_gyroscope : 0.0005898018182536241
# bin31_std_y_val_gyroscope : 0.0005887766322297185
# bin16_5_percentile_y_val_gyroscope : 0.0005887081489312041
# bin33_std_x_val_gyroscope : 0.0005885974021256388
# bin4_med_x_val_gyroscope : 0.0005882716502662441
# bin3_med_x_val_gyroscope : 0.0005879135171303388
# bin6_med_x_val_accelerometer : 0.0005868299222834523
# bin34_75_percentile_x_val_accelerometer : 0.0005866521339106755
# bin10_95_percentile_z_val_accelerometer : 0.0005839275851412944
# bin19_75_percentile_z_val_gyroscope : 0.0005833478279979177
# bin4_avg_z_val_gyroscope : 0.0005821371033185573
# bin2_avg_y_val_gyroscope : 0.0005803949064121975
# bin13_max_x_val_gyroscope : 0.0005787450505305459
# bin1_75_percentile_y_val_accelerometer : 0.0005787429565454955
# bin12_5_percentile_y_val_accelerometer : 0.0005752643451780649
# bin8_std_x_val_accelerometer : 0.0005747528212240416
# bin3_max_z_val_accelerometer : 0.0005734438438696624
# bin15_std_z_val_gyroscope : 0.00057016205035333
# bin17_25_percentile_y_val_gyroscope : 0.0005700234273733175
# bin27_95_percentile_y_val_gyroscope : 0.000569398653542792
# bin28_5_percentile_y_val_gyroscope : 0.0005687829222844259
# bin5_min_x_val_accelerometer : 0.0005673192634656151
# bin22_max_x_val_gyroscope : 0.0005670230339498775
# bin31_med_z_val_gyroscope : 0.0005669217657013314
# bin17_max_x_val_accelerometer : 0.0005664897219704524
# bin9_avg_z_val_gyroscope : 0.0005652694996600817
# bin29_med_z_val_gyroscope : 0.0005650864119232603
# bin9_max_y_val_gyroscope : 0.0005648402272777597
# bin7_max_y_val_accelerometer : 0.0005644908164931786
# bin14_max_x_val_gyroscope : 0.000563829023069828
# bin34_75_percentile_y_val_gyroscope : 0.0005629638945941152
# bin35_75_percentile_z_val_gyroscope : 0.0005617282445428736
# bin24_95_percentile_z_val_gyroscope : 0.0005614003499747818
# bin29_min_y_val_accelerometer : 0.0005613218116405287
# bin26_avg_x_val_accelerometer : 0.0005612179519640219
# bin17_min_y_val_accelerometer : 0.0005608994350004903
# bin19_5_percentile_z_val_accelerometer : 0.0005604549512362498
# bin10_avg_y_val_accelerometer : 0.0005589405803268431
# bin9_min_z_val_gyroscope : 0.0005567453021907504
# bin34_med_x_val_gyroscope : 0.0005545698895156421
# bin16_25_percentile_x_val_accelerometer : 0.0005542778784872754
# bin15_max_y_val_accelerometer : 0.0005512873442260571
# bin11_med_x_val_gyroscope : 0.000549696695153601
# bin16_max_z_val_gyroscope : 0.0005488236239612632
# bin15_5_percentile_x_val_gyroscope : 0.0005487969085913298
# bin20_25_percentile_y_val_gyroscope : 0.0005487524955313893
# global_5_percentile_y_val_accelerometer : 0.0005478490437908158
# bin32_5_percentile_x_val_gyroscope : 0.0005475883989246071
# bin11_med_y_val_accelerometer : 0.0005458223811658118
# bin18_25_percentile_x_val_accelerometer : 0.0005451230617708511
# bin19_5_percentile_x_val_gyroscope : 0.0005423388039485081
# bin23_min_z_val_gyroscope : 0.0005409761895380903
# bin7_med_x_val_accelerometer : 0.0005394232030320426
# bin33_max_x_val_gyroscope : 0.0005390369930278881
# bin29_max_x_val_gyroscope : 0.0005384332721532792
# bin9_std_z_val_accelerometer : 0.0005368579919950165
# bin1_5_percentile_y_val_accelerometer : 0.0005346512161347814
# bin21_avg_x_val_gyroscope : 0.0005343513602835599
# bin15_min_x_val_accelerometer : 0.0005336653863623734
# bin9_25_percentile_y_val_gyroscope : 0.000531874696997734
# bin20_avg_z_val_accelerometer : 0.0005311496615056125
# bin40_avg_x_val_gyroscope : 0.0005303066112727393
# bin27_max_y_val_accelerometer : 0.00052951170576974
# bin10_75_percentile_z_val_accelerometer : 0.0005290931426095025
# bin29_5_percentile_z_val_gyroscope : 0.0005287646623802803
# bin20_max_z_val_accelerometer : 0.0005280081259369244
# bin17_25_percentile_z_val_gyroscope : 0.0005269912496299302
# bin19_75_percentile_x_val_gyroscope : 0.0005268404234915717
# bin8_95_percentile_x_val_accelerometer : 0.0005254625967698971
# bin1_5_percentile_x_val_accelerometer : 0.0005252738445962594
# bin6_95_percentile_z_val_gyroscope : 0.0005221897638603663
# global_min_x_val_gyroscope : 0.0005216424558809539
# bin27_avg_z_val_accelerometer : 0.0005211949052531316
# bin37_max_y_val_gyroscope : 0.0005205852694187755
# bin30_med_z_val_gyroscope : 0.0005196289217773297
# bin8_max_z_val_accelerometer : 0.0005189418690987345
# bin3_med_z_val_accelerometer : 0.0005189304833394978
# bin26_25_percentile_y_val_accelerometer : 0.0005188079258932688
# bin22_avg_y_val_accelerometer : 0.000518694869257833
# bin39_avg_z_val_gyroscope : 0.0005186861669463737
# bin37_std_x_val_gyroscope : 0.0005178102693769149
# bin30_5_percentile_x_val_gyroscope : 0.0005177188335939205
# bin18_75_percentile_x_val_gyroscope : 0.0005176071881287213
# bin33_5_percentile_y_val_accelerometer : 0.0005174707018088054
# bin29_25_percentile_x_val_accelerometer : 0.0005158147478616722
# bin16_avg_x_val_gyroscope : 0.0005151760545764219
# bin11_95_percentile_y_val_gyroscope : 0.0005146577120062548
# bin7_med_z_val_accelerometer : 0.0005124608627730538
# bin26_max_x_val_accelerometer : 0.0005121890955382629
# bin24_avg_y_val_gyroscope : 0.0005110226249365088
# bin9_min_y_val_accelerometer : 0.0005099920915334986
# bin24_25_percentile_y_val_accelerometer : 0.0005086875184304391
# bin37_min_y_val_accelerometer : 0.0005082480815685318
# bin24_5_percentile_x_val_gyroscope : 0.0005072156424629575
# bin39_95_percentile_y_val_accelerometer : 0.000506240505949201
# bin31_5_percentile_x_val_accelerometer : 0.0005061282825929842
# bin3_max_x_val_accelerometer : 0.0005044929143277531
# global_med_y_val_accelerometer : 0.0005024474570685068
# bin2_25_percentile_z_val_accelerometer : 0.0005013690648792184
# bin36_min_y_val_gyroscope : 0.0005013133087651278
# bin13_max_y_val_gyroscope : 0.0005002363265101798
# bin25_5_percentile_z_val_accelerometer : 0.0004995502329393229
# bin15_min_y_val_gyroscope : 0.000498889111373009
# bin5_med_y_val_gyroscope : 0.0004980685179344753
# bin39_std_x_val_gyroscope : 0.000496837764021232
# bin35_75_percentile_x_val_gyroscope : 0.0004960759122614181
# bin33_75_percentile_x_val_gyroscope : 0.0004960359877836125
# bin6_max_z_val_gyroscope : 0.0004955868211300135
# bin6_max_y_val_gyroscope : 0.0004953831485904746
# bin14_std_z_val_gyroscope : 0.0004946686094106775
# bin25_25_percentile_z_val_gyroscope : 0.0004943587607314821
# bin11_std_z_val_accelerometer : 0.0004922168691187473
# bin12_min_x_val_accelerometer : 0.0004918440926676888
# bin28_25_percentile_y_val_accelerometer : 0.0004909537575674064
# bin23_75_percentile_y_val_accelerometer : 0.0004904636925619089
# bin22_avg_z_val_accelerometer : 0.0004903443512133837
# bin13_std_z_val_accelerometer : 0.0004897631308248468
# bin3_75_percentile_z_val_accelerometer : 0.0004897417667517694
# bin7_5_percentile_y_val_accelerometer : 0.0004891513697424726
# bin1_std_z_val_gyroscope : 0.00048763011998852754
# bin34_max_x_val_gyroscope : 0.0004875759992746994
# bin15_avg_y_val_gyroscope : 0.00048704928074184555
# bin6_min_y_val_gyroscope : 0.00048467386098514974
# bin3_5_percentile_y_val_accelerometer : 0.0004840636658461105
# bin21_95_percentile_x_val_accelerometer : 0.00048381225691953336
# bin19_25_percentile_y_val_gyroscope : 0.0004837476779489283
# bin1_std_y_val_accelerometer : 0.00048371580060079433
# bin18_max_y_val_accelerometer : 0.0004834595107583988
# bin15_5_percentile_x_val_accelerometer : 0.000482576695384912
# bin40_min_y_val_accelerometer : 0.00048246816084941756
# bin28_std_y_val_accelerometer : 0.00048211082070822296
# bin3_5_percentile_x_val_gyroscope : 0.000482091204994237
# bin18_min_z_val_accelerometer : 0.00048189903365522405
# bin36_avg_x_val_accelerometer : 0.0004816976584425903
# bin33_25_percentile_z_val_gyroscope : 0.0004811934665912577
# bin13_avg_y_val_accelerometer : 0.0004809857314587366
# bin10_95_percentile_x_val_accelerometer : 0.0004807420803700326
# bin22_std_z_val_accelerometer : 0.0004795965491385539
# bin13_75_percentile_x_val_accelerometer : 0.00047913467222142803
# bin1_std_x_val_gyroscope : 0.0004779711055555052
# bin11_95_percentile_x_val_gyroscope : 0.00047691025926626524
# bin5_avg_z_val_accelerometer : 0.0004767399124734865
# bin15_75_percentile_z_val_accelerometer : 0.0004730988361715734
# bin34_avg_z_val_accelerometer : 0.0004728931194974879
# bin9_max_z_val_gyroscope : 0.0004727421535556531
# bin30_std_y_val_gyroscope : 0.00047233795435301646
# bin12_95_percentile_y_val_gyroscope : 0.0004710516679711394
# bin34_max_z_val_gyroscope : 0.0004709575578981378
# bin23_95_percentile_y_val_accelerometer : 0.0004705539954560934
# bin35_5_percentile_y_val_accelerometer : 0.00047019528614021294
# bin38_95_percentile_x_val_accelerometer : 0.0004685105168573643
# bin25_95_percentile_x_val_gyroscope : 0.0004669541114875274
# bin9_min_x_val_gyroscope : 0.00046488216780345317
# bin26_75_percentile_x_val_accelerometer : 0.00046443858861040387
# bin6_med_y_val_gyroscope : 0.0004625148963040114
# bin36_min_x_val_gyroscope : 0.00046239012221867883
# bin14_med_z_val_gyroscope : 0.0004595003956564529
# bin33_max_y_val_accelerometer : 0.00045870119823709037
# bin18_min_x_val_accelerometer : 0.00045869505917550305
# bin27_25_percentile_x_val_gyroscope : 0.00045775213479135637
# bin3_std_z_val_gyroscope : 0.0004574117472424008
# bin33_95_percentile_y_val_accelerometer : 0.0004561133681487538
# bin35_med_y_val_gyroscope : 0.00045595766666922866
# bin34_std_x_val_gyroscope : 0.00045482919647717423
# bin18_med_y_val_gyroscope : 0.00045459206996323754
# bin3_95_percentile_y_val_gyroscope : 0.0004543190055036957
# bin14_std_x_val_gyroscope : 0.0004531012710527559
# bin3_std_y_val_gyroscope : 0.0004529986482295614
# bin16_min_y_val_accelerometer : 0.00045273759182314695
# bin18_95_percentile_x_val_accelerometer : 0.0004519965798462584
# bin37_min_z_val_accelerometer : 0.0004517172722747636
# bin37_std_y_val_gyroscope : 0.0004502525387127866
# bin1_max_y_val_accelerometer : 0.00044928118607427583
# bin32_std_y_val_gyroscope : 0.0004489912877009651
# bin35_95_percentile_y_val_gyroscope : 0.00044880706486844673
# bin29_std_y_val_accelerometer : 0.000448501967973842
# bin35_med_y_val_accelerometer : 0.0004471624468144292
# bin22_75_percentile_y_val_gyroscope : 0.00044698599637556404
# bin11_med_z_val_gyroscope : 0.000446943937717714
# bin22_5_percentile_y_val_gyroscope : 0.000446641784056045
# bin9_5_percentile_x_val_gyroscope : 0.0004465261101244781
# bin33_med_z_val_gyroscope : 0.0004463485638968426
# bin23_max_x_val_accelerometer : 0.00044472811973928086
# bin11_std_y_val_gyroscope : 0.00044241338725806595
# bin14_max_z_val_gyroscope : 0.00044239333973759625
# bin22_95_percentile_y_val_gyroscope : 0.0004423911495516177
# bin5_std_y_val_gyroscope : 0.00043969229377339997
# bin33_std_x_val_accelerometer : 0.0004395116537180909
# bin30_avg_y_val_gyroscope : 0.00043914014597184656
# bin13_5_percentile_x_val_accelerometer : 0.0004387341843734703
# bin20_max_y_val_accelerometer : 0.0004374509193390265
# bin21_5_percentile_y_val_accelerometer : 0.0004373153299237458
# bin11_95_percentile_y_val_accelerometer : 0.0004354487636646383
# bin1_5_percentile_y_val_gyroscope : 0.0004353055082006465
# bin31_avg_z_val_accelerometer : 0.00043511182676370905
# bin32_max_x_val_gyroscope : 0.00043486578919649813
# bin11_min_y_val_gyroscope : 0.0004348370213443979
# bin1_75_percentile_y_val_gyroscope : 0.0004347585873365323
# bin29_med_y_val_accelerometer : 0.00043465247725462216
# bin2_avg_x_val_gyroscope : 0.0004343606935057053
# bin39_max_x_val_accelerometer : 0.0004338348318547925
# bin27_5_percentile_z_val_accelerometer : 0.0004338137410600568
# bin34_avg_x_val_accelerometer : 0.00043341647152240326
# bin11_min_z_val_gyroscope : 0.0004333887911989299
# bin29_95_percentile_y_val_gyroscope : 0.00043217037971136316
# bin27_75_percentile_x_val_accelerometer : 0.0004306497081811824
# bin37_75_percentile_z_val_gyroscope : 0.0004304747811171099
# bin18_min_y_val_accelerometer : 0.0004300281643258863
# bin1_med_x_val_accelerometer : 0.00042958240062058783
# bin33_avg_y_val_gyroscope : 0.00042952092798036
# bin37_avg_x_val_gyroscope : 0.0004294242203732321
# bin4_25_percentile_y_val_accelerometer : 0.00042778002052782385
# bin39_max_y_val_accelerometer : 0.0004275314575524841
# bin12_25_percentile_x_val_gyroscope : 0.0004263112251892045
# bin35_5_percentile_z_val_accelerometer : 0.00042502673966094334
# bin21_5_percentile_z_val_gyroscope : 0.0004230699350492309
# bin21_75_percentile_y_val_gyroscope : 0.0004211345084543041
# bin4_75_percentile_z_val_accelerometer : 0.0004204601530700446
# bin37_avg_z_val_gyroscope : 0.0004185856401561232
# bin2_5_percentile_z_val_accelerometer : 0.000418381655427332
# bin3_std_x_val_gyroscope : 0.0004173033441800299
# bin29_5_percentile_z_val_accelerometer : 0.0004169447823644996
# bin6_75_percentile_y_val_accelerometer : 0.00041687428114448683
# bin30_std_y_val_accelerometer : 0.00041685694092130876
# bin2_25_percentile_y_val_accelerometer : 0.00041564047286252415
# bin35_max_x_val_accelerometer : 0.0004152741283832566
# bin17_min_z_val_accelerometer : 0.00041515230377233347
# bin20_min_x_val_gyroscope : 0.00041482847963388405
# bin29_75_percentile_z_val_gyroscope : 0.00041328166907591646
# bin21_95_percentile_x_val_gyroscope : 0.0004125634690172485
# bin9_std_x_val_gyroscope : 0.0004121524160710439
# bin12_25_percentile_z_val_gyroscope : 0.0004102098249813441
# bin27_5_percentile_y_val_gyroscope : 0.0004090887209056281
# bin3_5_percentile_z_val_accelerometer : 0.0004090730470749899
# bin35_25_percentile_z_val_accelerometer : 0.0004071696320612702
# bin21_25_percentile_x_val_gyroscope : 0.00040581482937079004
# bin9_5_percentile_y_val_accelerometer : 0.00040579256360078305
# global_med_y_val_gyroscope : 0.0004053579751602131
# bin35_std_z_val_gyroscope : 0.00040472269185626053
# bin11_25_percentile_y_val_gyroscope : 0.0004028805381434478
# bin22_75_percentile_z_val_gyroscope : 0.00040278453243123435
# bin28_95_percentile_x_val_accelerometer : 0.00040272730221524103
# bin9_med_y_val_accelerometer : 0.0004021179593824413
# bin34_5_percentile_x_val_gyroscope : 0.0004018471831005195
# bin6_std_y_val_gyroscope : 0.00040132868551468425
# bin8_25_percentile_y_val_gyroscope : 0.0004011215080596454
# bin31_avg_x_val_accelerometer : 0.00039908564501117515
# bin25_75_percentile_y_val_gyroscope : 0.0003983775513210676
# bin21_95_percentile_y_val_gyroscope : 0.00039743672321959633
# bin12_med_y_val_accelerometer : 0.00039683652667544107
# bin30_75_percentile_z_val_accelerometer : 0.0003962821088805342
# bin16_med_y_val_gyroscope : 0.00039438275206090366
# bin13_max_z_val_gyroscope : 0.0003939690285903847
# bin25_max_y_val_gyroscope : 0.0003922333757274305
# bin18_med_x_val_gyroscope : 0.00039161812554368454
# bin25_std_z_val_gyroscope : 0.0003913072270498936
# bin38_avg_z_val_accelerometer : 0.00039013195148245776
# bin40_95_percentile_x_val_gyroscope : 0.00038998200103210857
# bin39_75_percentile_x_val_accelerometer : 0.00038948330226190906
# bin28_std_y_val_gyroscope : 0.00038920755887309627
# bin36_75_percentile_x_val_accelerometer : 0.0003882315692260569
# bin3_25_percentile_x_val_accelerometer : 0.000387505834845767
# bin38_95_percentile_z_val_gyroscope : 0.00038702225533455596
# bin3_95_percentile_y_val_accelerometer : 0.00038699412907761913
# bin9_med_z_val_gyroscope : 0.00038636441674789676
# bin27_95_percentile_y_val_accelerometer : 0.000386348264724347
# bin19_75_percentile_x_val_accelerometer : 0.00038628497492722514
# bin21_95_percentile_z_val_gyroscope : 0.0003852023107869578
# bin11_25_percentile_x_val_gyroscope : 0.00038519711674347637
# bin38_5_percentile_x_val_accelerometer : 0.0003851003040292121
# bin4_max_x_val_gyroscope : 0.0003850596566447669
# bin2_max_y_val_accelerometer : 0.0003842911537807827
# bin6_max_y_val_accelerometer : 0.0003840975900126801
# global_5_percentile_z_val_gyroscope : 0.00038393192855284156
# bin19_75_percentile_y_val_gyroscope : 0.00038391325854349406
# bin40_med_y_val_accelerometer : 0.0003831000065961146
# bin7_min_z_val_accelerometer : 0.0003825691678322019
# bin40_std_x_val_accelerometer : 0.0003814387505935494
# bin7_75_percentile_y_val_gyroscope : 0.0003805202661826979
# bin31_min_y_val_accelerometer : 0.00037886059012517547
# bin36_med_z_val_accelerometer : 0.00037849504642314393
# bin13_max_y_val_accelerometer : 0.0003773555208411214
# bin32_avg_z_val_gyroscope : 0.0003766435174230595
# bin10_min_z_val_accelerometer : 0.00037605407242381924
# bin1_25_percentile_z_val_accelerometer : 0.00037480277151876563
# bin13_min_x_val_accelerometer : 0.0003738380672301217
# bin5_5_percentile_x_val_gyroscope : 0.000373723450419028
# bin38_95_percentile_z_val_accelerometer : 0.00037270393808551774
# bin24_25_percentile_x_val_accelerometer : 0.00037200443836563453
# bin19_max_y_val_accelerometer : 0.00037061463477407647
# bin32_max_y_val_accelerometer : 0.000370496594809192
# bin15_avg_z_val_accelerometer : 0.0003704471700480504
# bin18_std_x_val_gyroscope : 0.0003700713395529883
# bin17_75_percentile_z_val_gyroscope : 0.00036995819789896727
# bin15_avg_y_val_accelerometer : 0.0003698084104242987
# bin18_25_percentile_x_val_gyroscope : 0.0003697261193575267
# bin1_std_x_val_accelerometer : 0.0003695835060452734
# bin40_med_x_val_accelerometer : 0.0003689728980860663
# bin38_25_percentile_y_val_gyroscope : 0.0003687300632281986
# bin23_25_percentile_x_val_accelerometer : 0.00036872120340861105
# bin22_75_percentile_x_val_gyroscope : 0.0003686991323039096
# bin12_max_x_val_accelerometer : 0.00036815915793682774
# bin28_25_percentile_x_val_accelerometer : 0.0003676867516081019
# bin34_max_x_val_accelerometer : 0.00036744348902033953
# bin25_max_z_val_gyroscope : 0.00036733143451216663
# bin10_25_percentile_z_val_gyroscope : 0.00036661267188817806
# bin6_75_percentile_x_val_accelerometer : 0.00036622253464696134
# bin13_std_x_val_gyroscope : 0.00036592708696959276
# global_avg_x_val_accelerometer : 0.0003655496149195416
# bin12_5_percentile_z_val_gyroscope : 0.00036501159762097776
# bin2_std_x_val_accelerometer : 0.0003626988478400441
# bin25_std_x_val_accelerometer : 0.00036231703605671194
# bin11_75_percentile_y_val_gyroscope : 0.00036210679372168214
# bin21_min_y_val_accelerometer : 0.00036101955515497334
# bin40_75_percentile_y_val_gyroscope : 0.0003583466027979965
# bin4_std_z_val_gyroscope : 0.00035834517869942184
# bin36_75_percentile_y_val_accelerometer : 0.0003573946790879726
# bin4_avg_y_val_gyroscope : 0.00035618805458391775
# bin36_max_x_val_accelerometer : 0.0003559346968885016
# bin21_std_x_val_gyroscope : 0.00035568780716305133
# bin26_max_z_val_gyroscope : 0.00035414916528137317
# bin37_min_z_val_gyroscope : 0.0003539323148409651
# bin10_med_z_val_accelerometer : 0.00035355005642192985
# bin1_std_y_val_gyroscope : 0.0003531185938714308
# bin11_med_z_val_accelerometer : 0.00035244483449501057
# bin38_95_percentile_y_val_accelerometer : 0.0003522638761895088
# bin4_min_y_val_gyroscope : 0.0003520492849326085
# bin26_25_percentile_z_val_accelerometer : 0.00035103946886919253
# bin10_5_percentile_z_val_gyroscope : 0.0003508437562040894
# bin37_5_percentile_x_val_accelerometer : 0.0003504015550667555
# bin11_max_x_val_gyroscope : 0.00035032591067683116
# bin22_max_y_val_gyroscope : 0.0003478707070002277
# bin17_min_z_val_gyroscope : 0.0003474629502541487
# bin36_75_percentile_x_val_gyroscope : 0.0003472702618559249
# bin37_max_z_val_accelerometer : 0.0003462277664620564
# bin4_std_y_val_accelerometer : 0.000345636750323214
# bin16_5_percentile_x_val_gyroscope : 0.0003455720502688394
# bin18_25_percentile_y_val_accelerometer : 0.0003453779289967506
# bin15_25_percentile_x_val_gyroscope : 0.00034496505774069555
# bin33_std_y_val_accelerometer : 0.00034475667383547526
# bin20_5_percentile_z_val_gyroscope : 0.00034408830480284707
# bin6_avg_x_val_accelerometer : 0.00034174379237522374
# bin36_min_z_val_gyroscope : 0.0003410771309144142
# bin15_med_z_val_gyroscope : 0.00034100814815613576
# bin35_max_z_val_gyroscope : 0.0003410055399701149
# bin12_max_x_val_gyroscope : 0.0003409554512310255
# bin40_max_z_val_accelerometer : 0.00033998779965278017
# bin21_min_z_val_gyroscope : 0.000339908182984904
# bin28_med_x_val_accelerometer : 0.00033936571300016927
# ...
# bin38_min_z_val_accelerometer : 0.0001103084508657267
# bin19_max_x_val_accelerometer : 0.00010998415252773534
# bin27_avg_x_val_gyroscope : 0.00010986993667652508
# bin38_95_percentile_x_val_gyroscope : 0.00010977812177502563
# bin38_25_percentile_x_val_gyroscope : 0.00010971015929999833
# bin7_5_percentile_z_val_gyroscope : 0.00010948970465586784
# bin38_std_z_val_accelerometer : 0.00010931568520768082
# bin13_25_percentile_y_val_accelerometer : 0.00010923951861662424
# bin5_95_percentile_x_val_gyroscope : 0.00010896994065725023
# bin16_75_percentile_z_val_gyroscope : 0.00010896583047091136
# bin7_med_z_val_gyroscope : 0.0001084571350238697
# bin20_5_percentile_z_val_accelerometer : 0.00010837310420690691
# bin23_25_percentile_z_val_accelerometer : 0.0001082754403955496
# bin29_avg_z_val_accelerometer : 0.00010789472725975336
# bin21_avg_z_val_gyroscope : 0.00010781892243460761
# bin40_5_percentile_y_val_accelerometer : 0.00010777432104583635
# bin26_75_percentile_z_val_gyroscope : 0.00010776435527646231
# bin26_95_percentile_x_val_gyroscope : 0.00010775853488603585
# bin11_25_percentile_z_val_accelerometer : 0.00010771894265854599
# bin6_25_percentile_y_val_gyroscope : 0.00010763475731628587
# bin32_75_percentile_z_val_accelerometer : 0.00010756631758796898
# bin32_max_y_val_gyroscope : 0.00010713960180736245
# bin22_25_percentile_x_val_gyroscope : 0.00010711087811762791
# bin33_min_x_val_accelerometer : 0.00010674385142708205
# bin31_25_percentile_z_val_gyroscope : 0.00010660559876811281
# bin26_75_percentile_y_val_accelerometer : 0.0001063798394711991
# bin38_min_z_val_gyroscope : 0.00010634671251556322
# bin12_min_x_val_gyroscope : 0.0001061822894141684
# bin17_med_y_val_gyroscope : 0.00010613940755121544
# bin18_max_x_val_gyroscope : 0.00010613508049405478
# bin37_min_y_val_gyroscope : 0.00010593211904050976
# bin15_75_percentile_y_val_gyroscope : 0.00010575553415509871
# bin22_min_x_val_accelerometer : 0.00010570871083785545
# bin30_avg_z_val_accelerometer : 0.00010570778469916822
# bin26_75_percentile_x_val_gyroscope : 0.0001055189047315032
# bin15_min_y_val_accelerometer : 0.00010535830028626192
# bin3_min_y_val_gyroscope : 0.00010532478547924362
# bin17_25_percentile_x_val_accelerometer : 0.00010520573704017204
# bin3_25_percentile_y_val_gyroscope : 0.00010516202491025483
# bin31_95_percentile_x_val_accelerometer : 0.000105131405996088
# bin33_75_percentile_x_val_accelerometer : 0.00010502720180139525
# bin32_95_percentile_z_val_accelerometer : 0.00010497316368276851
# bin15_avg_x_val_gyroscope : 0.00010496897915556743
# bin34_5_percentile_z_val_gyroscope : 0.0001049498138215674
# bin25_5_percentile_z_val_gyroscope : 0.00010457683502329364
# bin1_25_percentile_y_val_gyroscope : 0.00010452006953048586
# bin26_95_percentile_x_val_accelerometer : 0.00010447534106634401
# bin35_avg_y_val_gyroscope : 0.0001044709388971684
# bin29_min_z_val_accelerometer : 0.00010442260442260441
# bin33_95_percentile_y_val_gyroscope : 0.00010431648606785012
# bin29_min_y_val_gyroscope : 0.00010428721561611006
# bin11_min_x_val_accelerometer : 0.00010417245556583415
# bin15_min_x_val_gyroscope : 0.0001040301160158876
# bin21_std_z_val_accelerometer : 0.00010382268298274237
# bin31_std_x_val_accelerometer : 0.0001038005879773881
# bin1_5_percentile_z_val_gyroscope : 0.00010371128290260317
# bin27_max_z_val_gyroscope : 0.00010370536139809953
# bin34_std_z_val_gyroscope : 0.000103519489513257
# bin26_75_percentile_y_val_gyroscope : 0.00010349473925632877
# bin15_75_percentile_z_val_gyroscope : 0.00010344112098539899
# bin6_min_z_val_gyroscope : 0.00010329245126104082
# bin21_avg_y_val_gyroscope : 0.00010323419820966054
# bin28_max_x_val_accelerometer : 0.0001031796012545752
# bin5_75_percentile_x_val_gyroscope : 0.0001031740401819143
# bin5_min_y_val_gyroscope : 0.00010306468078894724
# global_5_percentile_x_val_accelerometer : 0.00010301320646148238
# bin22_avg_z_val_gyroscope : 0.00010298201590728925
# bin11_max_y_val_gyroscope : 0.00010294282197605465
# bin12_75_percentile_y_val_accelerometer : 0.00010288694344407099
# bin10_75_percentile_y_val_gyroscope : 0.00010285547085681589
# bin33_avg_z_val_accelerometer : 0.00010281383299491227
# bin31_25_percentile_x_val_accelerometer : 0.00010277150720713681
# bin28_25_percentile_y_val_gyroscope : 0.00010266301642608273
# bin34_min_y_val_gyroscope : 0.00010254861564000716
# bin26_min_y_val_gyroscope : 0.00010216030781006177
# bin20_25_percentile_y_val_accelerometer : 0.00010216030781006174
# bin36_95_percentile_y_val_gyroscope : 0.0001021190804899963
# bin9_std_y_val_accelerometer : 0.00010199821572414742
# bin5_max_x_val_gyroscope : 0.00010198291890643181
# bin30_5_percentile_y_val_accelerometer : 0.00010166081088293508
# bin7_25_percentile_z_val_gyroscope : 0.0001015711983453924
# bin4_med_z_val_accelerometer : 0.00010148475178883068
# bin19_std_x_val_accelerometer : 0.00010147303908392007
# bin1_25_percentile_z_val_gyroscope : 0.00010146856400813308
# bin40_5_percentile_x_val_gyroscope : 0.00010130289767937098
# bin12_avg_y_val_gyroscope : 0.0001011109016130839
# bin3_95_percentile_z_val_accelerometer : 0.00010095591962219012
# bin16_med_z_val_gyroscope : 0.00010062186499053403
# bin38_25_percentile_x_val_accelerometer : 0.00010022177538962177
# bin35_std_x_val_accelerometer : 9.994616244259369e-05
# bin35_95_percentile_x_val_gyroscope : 9.98923355628223e-05
# bin8_max_y_val_accelerometer : 9.977010715570022e-05
# bin24_95_percentile_x_val_accelerometer : 9.97195907540735e-05
# bin15_std_x_val_gyroscope : 9.964592527528067e-05
# bin27_5_percentile_x_val_gyroscope : 9.963282374074369e-05
# bin24_std_z_val_gyroscope : 9.881405817174515e-05
# bin9_max_x_val_gyroscope : 9.88128816291107e-05
# bin6_5_percentile_z_val_accelerometer : 9.878655419119945e-05
# bin7_75_percentile_x_val_accelerometer : 9.877626901380981e-05
# bin34_min_z_val_accelerometer : 9.862645565840547e-05
# bin38_std_x_val_gyroscope : 9.848431108273633e-05
# bin30_std_z_val_gyroscope : 9.815462542522751e-05
# bin7_25_percentile_x_val_gyroscope : 9.792360340362559e-05
# bin25_std_z_val_accelerometer : 9.751466045048009e-05
# bin12_5_percentile_y_val_gyroscope : 9.715477714339973e-05
# bin18_95_percentile_x_val_gyroscope : 9.69988020329615e-05
# bin30_min_z_val_accelerometer : 9.694960212201594e-05
# bin40_95_percentile_z_val_accelerometer : 9.689081215916912e-05
# bin29_95_percentile_z_val_gyroscope : 9.673235083071147e-05
# bin14_25_percentile_z_val_gyroscope : 9.660801694821664e-05
# bin13_95_percentile_y_val_gyroscope : 9.634120353770013e-05
# bin14_avg_z_val_gyroscope : 9.631801086268076e-05
# bin17_avg_y_val_gyroscope : 9.624062222283469e-05
# bin39_75_percentile_y_val_accelerometer : 9.606807936163531e-05
# bin29_avg_x_val_gyroscope : 9.606807936163531e-05
# bin36_25_percentile_y_val_accelerometer : 9.588683189011647e-05
# bin31_avg_z_val_gyroscope : 9.577747995875999e-05
# bin9_avg_x_val_gyroscope : 9.529675744643414e-05
# bin31_min_z_val_accelerometer : 9.497103881340339e-05
# bin30_avg_x_val_gyroscope : 9.472258805404948e-05
# bin3_med_y_val_accelerometer : 9.471879183226635e-05
# bin5_75_percentile_x_val_accelerometer : 9.457134526402872e-05
# bin20_95_percentile_z_val_accelerometer : 9.438195062425738e-05
# bin18_avg_y_val_gyroscope : 9.43805936085224e-05
# bin14_5_percentile_y_val_gyroscope : 9.381477450191667e-05
# bin29_avg_x_val_accelerometer : 9.378209803950767e-05
# bin35_max_x_val_gyroscope : 9.338847252214746e-05
# bin16_med_x_val_gyroscope : 9.333001493280238e-05
# bin6_95_percentile_x_val_gyroscope : 9.332736770856806e-05
# bin23_75_percentile_z_val_accelerometer : 9.330691974759286e-05
# bin4_25_percentile_x_val_gyroscope : 9.328345634078116e-05
# bin1_med_y_val_gyroscope : 9.326057467011957e-05
# bin17_5_percentile_z_val_accelerometer : 9.301695249359352e-05
# bin25_25_percentile_x_val_gyroscope : 9.262038726097652e-05
# bin7_med_y_val_accelerometer : 9.197010735931662e-05
# bin6_med_x_val_gyroscope : 9.190717244099661e-05
# bin36_std_y_val_gyroscope : 9.186604848543303e-05
# bin14_avg_x_val_gyroscope : 9.176373174192046e-05
# bin39_min_y_val_gyroscope : 9.17602297735835e-05
# bin7_min_x_val_gyroscope : 9.089400570130794e-05
# bin14_5_percentile_z_val_accelerometer : 9.084273237318495e-05
# bin14_med_y_val_gyroscope : 9.077342410675744e-05
# bin4_75_percentile_x_val_accelerometer : 8.969527398694304e-05
# bin21_25_percentile_y_val_gyroscope : 8.969527398694304e-05
# bin20_avg_y_val_gyroscope : 8.959681433549026e-05
# bin5_25_percentile_y_val_gyroscope : 8.805198837802472e-05
# bin20_75_percentile_z_val_gyroscope : 8.805198837802472e-05
# bin11_5_percentile_y_val_gyroscope : 8.796586489446055e-05
# bin12_25_percentile_x_val_accelerometer : 8.767123287671232e-05
# bin38_min_y_val_gyroscope : 8.760038876668887e-05
# bin22_med_y_val_gyroscope : 8.752995817020709e-05
# bin4_75_percentile_z_val_gyroscope : 8.705911574764035e-05
# bin37_max_x_val_gyroscope : 8.705911574764035e-05
# bin16_25_percentile_z_val_accelerometer : 8.684253163065407e-05
# bin15_25_percentile_x_val_accelerometer : 8.684253163065407e-05
# bin40_max_y_val_accelerometer : 8.654504156899281e-05
# bin27_75_percentile_y_val_gyroscope : 8.654504156899281e-05
# bin21_5_percentile_x_val_gyroscope : 8.616297416343437e-05
# bin27_std_z_val_accelerometer : 8.591331269349844e-05
# bin21_max_y_val_accelerometer : 8.591122359281622e-05
# bin25_25_percentile_y_val_accelerometer : 8.582273962502108e-05
# bin3_75_percentile_y_val_gyroscope : 8.538315988647117e-05
# bin34_avg_y_val_accelerometer : 8.527070063694267e-05
# bin33_25_percentile_z_val_accelerometer : 8.452194357366773e-05
# bin31_med_z_val_accelerometer : 8.441512378520256e-05
# bin24_std_y_val_gyroscope : 8.441512378520256e-05
# bin9_5_percentile_z_val_gyroscope : 8.399701343952218e-05
# bin29_std_y_val_gyroscope : 8.399181575811015e-05
# bin30_5_percentile_x_val_accelerometer : 8.393451720310765e-05
# bin9_75_percentile_x_val_accelerometer : 8.33583485348789e-05
# bin38_med_y_val_gyroscope : 8.296409820642779e-05
# bin23_min_z_val_accelerometer : 8.244976421469979e-05
# bin26_5_percentile_z_val_accelerometer : 8.235425758084372e-05
# bin21_max_y_val_gyroscope : 8.218185581948968e-05
# bin26_min_y_val_accelerometer : 8.180460513117716e-05
# bin5_max_y_val_accelerometer : 8.164355477914372e-05
# bin3_max_x_val_gyroscope : 8.143643619958039e-05
# bin15_95_percentile_x_val_accelerometer : 8.056144296898654e-05
# global_95_percentile_x_val_accelerometer : 7.970625899259499e-05
# bin31_max_z_val_accelerometer : 7.970625899259496e-05
# bin21_max_x_val_gyroscope : 7.970625899259496e-05
# bin1_max_z_val_accelerometer : 7.970625899259496e-05
# bin36_avg_z_val_gyroscope : 7.948149291860256e-05
# bin35_5_percentile_y_val_gyroscope : 7.905124653739612e-05
# bin39_max_z_val_accelerometer : 7.877696235318635e-05
# bin16_25_percentile_y_val_accelerometer : 7.817897875159715e-05
# bin9_avg_x_val_accelerometer : 7.70454898307716e-05
# bin27_med_y_val_accelerometer : 7.658931036749723e-05
# bin25_5_percentile_x_val_gyroscope : 7.588739290085686e-05
# bin22_max_z_val_accelerometer : 7.518621399957518e-05
# bin12_med_x_val_gyroscope : 7.513061650992687e-05
# bin6_std_x_val_accelerometer : 7.503566558684673e-05
# bin35_std_y_val_accelerometer : 7.411970023611542e-05
# bin15_75_percentile_x_val_gyroscope : 7.409630980878125e-05
# bin35_min_z_val_accelerometer : 7.340818381886682e-05
# bin23_std_x_val_gyroscope : 7.340818381886682e-05
# bin19_avg_x_val_gyroscope : 7.330488741205049e-05
# bin32_std_z_val_gyroscope : 7.329279257962238e-05
# bin33_min_y_val_gyroscope : 7.328867930195538e-05
# bin1_avg_y_val_gyroscope : 7.294163180850594e-05
# bin39_5_percentile_z_val_accelerometer : 7.289812067260138e-05
# bin33_5_percentile_x_val_accelerometer : 7.285595852357798e-05
# bin34_5_percentile_y_val_accelerometer : 7.271520456104638e-05
# bin17_75_percentile_x_val_accelerometer : 7.271520456104638e-05
# bin29_max_z_val_accelerometer : 7.261873928540598e-05
# bin13_avg_z_val_accelerometer : 7.261873928540598e-05
# bin30_95_percentile_y_val_accelerometer : 7.236877635887843e-05
# bin27_25_percentile_z_val_accelerometer : 7.189058697745075e-05
# bin7_med_x_val_gyroscope : 7.175621918955448e-05
# bin3_avg_x_val_accelerometer : 7.161017152798803e-05
# bin33_med_x_val_gyroscope : 7.161017152798803e-05
# bin18_min_z_val_gyroscope : 7.157192715547037e-05
# global_25_percentile_x_val_gyroscope : 7.087005904273792e-05
# bin22_std_x_val_gyroscope : 7.028408315637761e-05
# bin25_std_y_val_gyroscope : 6.8728978874253e-05
# bin36_75_percentile_z_val_accelerometer : 6.61980334101898e-05
# bin37_med_x_val_gyroscope : 6.0481501409342586e-05
# bin25_avg_z_val_gyroscope : 5.929070727304176e-05
# bin30_25_percentile_z_val_gyroscope : 5.8105685302228885e-05
# bin5_avg_x_val_gyroscope : 5.634796238244515e-05
# bin12_max_y_val_accelerometer : 5.5896759705010314e-05
# bin27_avg_y_val_accelerometer : 5.5776997767633654e-05
# bin32_5_percentile_z_val_gyroscope : 5.550252494149526e-05
# bin38_max_z_val_accelerometer : 5.540526082504165e-05
# bin22_std_y_val_accelerometer : 5.539977264115196e-05
# bin3_min_z_val_accelerometer : 5.5309398804285184e-05
# bin34_min_x_val_gyroscope : 5.524903351724657e-05
# bin34_75_percentile_y_val_accelerometer : 5.4792475365780844e-05
# bin1_avg_x_val_gyroscope : 5.470622385637946e-05
# bin9_min_x_val_accelerometer : 5.453640342078478e-05
# bin23_5_percentile_y_val_accelerometer : 5.4464054464054474e-05
# bin30_min_y_val_gyroscope : 5.4276582269158826e-05
# bin16_min_z_val_gyroscope : 5.4041893511454976e-05
# bin7_25_percentile_y_val_accelerometer : 5.3895537766505505e-05
# bin33_avg_x_val_gyroscope : 5.3895537766505505e-05
# bin13_min_x_val_gyroscope : 5.3895537766505505e-05
# bin18_5_percentile_y_val_gyroscope : 5.3674854399007464e-05
# bin22_max_y_val_accelerometer : 5.3309215182995494e-05
# bin39_med_y_val_gyroscope : 5.2861830335162844e-05
# bin32_25_percentile_y_val_accelerometer : 5.230472149218255e-05
# bin30_75_percentile_y_val_accelerometer : 5.2027285509168494e-05
# bin22_5_percentile_y_val_accelerometer : 5.15637402032913e-05
# bin26_max_x_val_gyroscope : 5.122542034767726e-05
# bin20_75_percentile_y_val_accelerometer : 5.064468148050743e-05
# bin6_95_percentile_y_val_gyroscope : 5.03213749037138e-05
# bin40_med_z_val_gyroscope : 5.007213199118833e-05
# bin26_95_percentile_y_val_accelerometer : 4.955310963800858e-05
# bin34_95_percentile_x_val_accelerometer : 4.954889438991526e-05
# bin36_5_percentile_y_val_gyroscope : 4.949610729862912e-05
# bin30_25_percentile_x_val_accelerometer : 4.737691805583698e-05
# bin2_5_percentile_y_val_gyroscope : 4.113410548821998e-05
# bin4_med_z_val_gyroscope : 3.700981511070552e-05
# bin27_avg_y_val_gyroscope : 3.554763461523382e-05
# bin31_75_percentile_x_val_accelerometer : 3.5124692658938925e-05
# bin7_avg_x_val_accelerometer : 3.430508656989475e-05
# bin30_min_y_val_accelerometer : 3.427034844785439e-05
# bin33_min_z_val_accelerometer : 3.381692956553186e-05
# bin23_25_percentile_y_val_accelerometer : 3.364346330290224e-05
# bin28_75_percentile_z_val_gyroscope : 3.347055906598143e-05
# bin5_5_percentile_y_val_accelerometer : 3.335376915956341e-05
# bin10_25_percentile_z_val_accelerometer : 3.2884398963324114e-05
# bin32_med_z_val_accelerometer : 3.272200954713433e-05
# bin2_25_percentile_x_val_accelerometer : 2.6347381606689008e-05
# bin15_25_percentile_z_val_accelerometer : 2.5735705494013662e-05
# bin5_med_y_val_accelerometer : 2.451209206382949e-05
# bin33_95_percentile_x_val_accelerometer : 2.3838665869331537e-05
# bin29_std_x_val_gyroscope : 2.3745111782160592e-05
# bin26_avg_z_val_gyroscope : 2.2840569504029576e-05
# bin24_5_percentile_y_val_gyroscope : 2.155749532798676e-05
# bin34_avg_x_val_gyroscope : 2.125618953782005e-05
# bin32_25_percentile_x_val_gyroscope : 2.0595537413054574e-05
# bin24_95_percentile_x_val_gyroscope : 1.8946569760534777e-05
# bin31_75_percentile_z_val_accelerometer : 1.7499130239157044e-05
# bin1_med_z_val_accelerometer : 1.715340276246701e-05
# bin25_max_x_val_accelerometer : 1.4970930099020308e-05
# bin24_min_y_val_gyroscope : 1.2915943184082518e-05
# bin31_max_x_val_gyroscope : 1.1236022972794215e-05
# bin11_75_percentile_z_val_gyroscope : 1.0156304534134371e-05
# bin38_75_percentile_x_val_accelerometer : 9.729704340007546e-06
# bin18_75_percentile_z_val_gyroscope : 8.34289416825577e-06
# bin26_max_y_val_accelerometer : 4.86477656238473e-06
# bin17_25_percentile_z_val_accelerometer : 3.5609637296230612e-06

# %%
unimportant_features = [featureIndex for featureIndex, featureName in enumerate(df.columns)
                        if featureIndex not in rf_tune_model.featureImportances.indices] # indices

unimportant_features = [features_dict[index] for index in unimportant_features]

# %% [markdown]
# __Features vector and Label vector for the selected set of features__
#
# We will use the features and label vectors built from this set of `important_features` as inputs for an alternative model of the following algorithms and compare the performance before and after feature selection

# %%
# recreate training and testing set

feature_cols = important_features
training_set_top, testing_set_top = create_train_test_sets(df, featureCols=important_features, labelCol='label', 
                                                   seed=1, splitRatio=[0.8, 0.2])

# %% [markdown]
# ## RandomForest - selected features

# %%
rf_top = RandomForestClassifier(maxDepth=30, numTrees=50, seed = 42)
rf_top_model, rf_top_training_time, rf_top_pred_time, rf_top_scores = run_model(clf=rf_top, evaluators=evaluators, 
                                             training_data=training_set_top, testing_data=testing_set_top)
# Out:
# Training time in seconds is 11.6944420337677.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    2|
# |    0|       0.0|   83|
# |    1|       1.0|   88|
# |    0|       1.0|    2|
# +-----+----------+-----+
#
# F1 score = 0.9771428571428572
# Accuracy score = 0.9771428571428571
# Test Error = 0.02285714285714291
# Weightedprecision score = 0.9771428571428572
# Weightedrecall score = 0.9771428571428572
#
# Predition time in seconds is: 0.11738920211791992

# %% [markdown]
# ## Logistic Regression - selected features

# %%
lr_top = LogisticRegression(regParam=0.01, maxIter=1000, fitIntercept=True)
lr_top_model, lr_top_training_time, lr_top_pred_time, lr_top_scores = run_model(clf=lr_top, evaluators=evaluators, 
                                                                                training_data=training_set_top, 
                                                                                testing_data=testing_set_top)
# Out:
# Training time in seconds is 58.973448753356934.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    7|
# |    0|       0.0|   77|
# |    1|       1.0|   83|
# |    0|       1.0|    8|
# +-----+----------+-----+
#
# F1 score = 0.9142689015192202
# Accuracy score = 0.9142857142857143
# Test Error = 0.08571428571428574
# Weightedprecision score = 0.9143118785975928
# Weightedrecall score = 0.9142857142857144
#
# Predition time in seconds is: 0.06215310096740723

# %% [markdown]
# ## Gradient-Boosted Tree - selected features

# %%
gbt_top = GBTClassifier(maxIter=50, seed=42)
gbt_top_model, gbt_top_training_time, gbt_top_pred_time, gbt_top_scores = run_model(clf=gbt_top, 
                                                                                    evaluators=evaluators, 
                                                                                    training_data=training_set_top,
                                                                                    testing_data=testing_set_top)
# Out:
# Training time in seconds is 210.01020503044128.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    2|
# |    0|       0.0|   84|
# |    1|       1.0|   88|
# |    0|       1.0|    1|
# +-----+----------+-----+
#
# F1 score = 0.982859383094608
# Accuracy score = 0.9828571428571429
# Test Error = 0.017142857142857126
# Weightedprecision score = 0.9829258277651274
# Weightedrecall score = 0.9828571428571429
#
# Predition time in seconds is: 0.1607198715209961

# %% [markdown]
# ## Linear SVM - selected features

# %%
svm_top = LinearSVC(maxIter=100, regParam=0.1)
svm_top_model, svm_top_training_time, svm_top_pred_time, svm_top_scores = run_model(clf=svm_top, 
                                                                                    evaluators=evaluators, 
                                                                                    training_data=training_set_top, 
                                                                                    testing_data=testing_set_top)
# Out:
# Training time in seconds is 24.847747802734375.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    8|
# |    0|       0.0|   73|
# |    1|       1.0|   82|
# |    0|       1.0|   12|
# +-----+----------+-----+
#
# F1 score = 0.8855795854224351
# Accuracy score = 0.8857142857142857
# Test Error = 0.11428571428571432
# Weightedprecision score = 0.8863747232541559
# Weightedrecall score = 0.8857142857142857
#
# Predition time in seconds is: 0.15775322914123535

# %% [markdown]
# ## OneVsRest - selected features

# %%
ovr_top = OneVsRest(classifier=lr)
ovr_top_model, ovr_top_training_time, ovr_top_pred_time, ovr_top_scores = run_model(clf=ovr_top, evaluators=evaluators, 
                                             training_data=training_set_top, testing_data=testing_set_top)
# Out:
# Training time in seconds is 113.96643733978271.
#
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |    1|       0.0|    7|
# |    0|       0.0|   77|
# |    1|       1.0|   83|
# |    0|       1.0|    8|
# +-----+----------+-----+
#
# F1 score = 0.9142689015192202
# Accuracy score = 0.9142857142857143
# Test Error = 0.08571428571428574
# Weightedprecision score = 0.9143118785975928
# Weightedrecall score = 0.9142857142857144
#
# Predition time in seconds is: 0.5405926704406738

# %% [markdown]
# # Model comparison

# %%
import pandas as pd

headers=["Model","F1 score", "Accuracy", "Precision",
        "Recall","Training Time (s)", "Prediction Time (s)"]

metrics=[("RandomForest", *rf_scores, rf_training_time, rf_pred_time),
         ("RandomForest - Hyperparameters Tuned", *rf_tune_scores, rf_tune_training_time, rf_pred_time),
         ("RandomForest - selected features", *rf_tune2_scores, rf_tune2_training_time, rf_tune2_pred_time),
         ("Logistic Regression", *lr_scores, lr_training_time, lr_pred_time), 
         ("Logistic Regression - selected features", *lr_top_scores, lr_top_training_time, lr_top_pred_time),
         ("Gradient-boosted tree classifier", *gbt_scores, gbt_training_time, gbt_pred_time),
         ("Gradient-boosted tree classifier - selected features",*gbt_top_scores, gbt_training_time, gbt_pred_time),
         ("Support Vector Machine", *svm_scores, svm_training_time, svm_pred_time),
         ("Support Vector Machine - selected features", *svm_top_scores, svm_top_training_time, svm_top_pred_time),
         ("OneVsRest", *ovr_scores, ovr_training_time, ovr_pred_time),
         ("OneVsRest - selected features", *ovr_top_scores, ovr_top_training_time, ovr_top_pred_time)]

df_metrics = pd.DataFrame.from_records(metrics, columns=headers).set_index('Model')

# %%
df_metrics.sort_values(by='F1 score', ascending=False)
# Out:
#                                                     F1 score  Accuracy  \
# Model
# Gradient-boosted tree classifier                    0.982859  0.982857
# Gradient-boosted tree classifier - selected fea...  0.982859  0.982857
# RandomForest - Hyperparameters Tuned                0.977143  0.977143
# RandomForest - selected features                    0.977143  0.977143
# Logistic Regression                                 0.914269  0.914286
# Logistic Regression - selected features             0.914269  0.914286
# OneVsRest                                           0.914269  0.914286
# OneVsRest - selected features                       0.914269  0.914286
# RandomForest                                        0.914145  0.914286
# Support Vector Machine                              0.885580  0.885714
# Support Vector Machine - selected features          0.885580  0.885714
#
#                                                     Precision    Recall  \
# Model
# Gradient-boosted tree classifier                     0.982926  0.982857
# Gradient-boosted tree classifier - selected fea...   0.982926  0.982857
# RandomForest - Hyperparameters Tuned                 0.977143  0.977143
# RandomForest - selected features                     0.977143  0.977143
# Logistic Regression                                  0.914312  0.914286
# Logistic Regression - selected features              0.914312  0.914286
# OneVsRest                                            0.914312  0.914286
# OneVsRest - selected features                        0.914312  0.914286
# RandomForest                                         0.915508  0.914286
# Support Vector Machine                               0.886375  0.885714
# Support Vector Machine - selected features           0.886375  0.885714
#
#                                                     Training Time (s)  \
# Model
# Gradient-boosted tree classifier                           208.784456
# Gradient-boosted tree classifier - selected fea...         208.784456
# RandomForest - Hyperparameters Tuned                        14.069913
# RandomForest - selected features                            13.312894
# Logistic Regression                                         60.914721
# Logistic Regression - selected features                     58.973449
# OneVsRest                                                  117.823248
# OneVsRest - selected features                              113.966437
# RandomForest                                                45.502581
# Support Vector Machine                                      20.618673
# Support Vector Machine - selected features                  24.847748
#
#                                                     Prediction Time (s)
# Model
# Gradient-boosted tree classifier                               0.126281
# Gradient-boosted tree classifier - selected fea...             0.126281
# RandomForest - Hyperparameters Tuned                           0.169024
# RandomForest - selected features                               0.139254
# Logistic Regression                                            0.125684
# Logistic Regression - selected features                        0.062153
# OneVsRest                                                      0.539303
# OneVsRest - selected features                                  0.540593
# RandomForest                                                   0.169024
# Support Vector Machine                                         0.063039
# Support Vector Machine - selected features                     0.157753

# %% [markdown]
# # Extra - Cross validation

# %% [markdown]
# We commented out this section as we have implemented the best model based on this code already above.

# %%
# rf_cv = RandomForestClassifier()
# evaluator_cv = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", 
#                                               metricName="accuracy")

# cv = CrossValidator().setEstimator(rf_cv).setEvaluator(evaluator_cv).setNumFolds(5)

# paramGrid = ParamGridBuilder().addGrid(rf_cv.numTrees, [30, 50, 70])\
#                               .addGrid(rf_cv.maxDepth, [10, 20, 30])\
#                               .addGrid(rf_cv.featureSubsetStrategy, ['auto', 'all', 'onethird'])\
#                               .build()

# cv.setEstimatorParamMaps(paramGrid)

# cvmodel = cv.fit(training_set_5)

# print(cvmodel.bestModel._java_obj.getNumTrees())
# print(cvmodel.bestModel._java_obj.getFeatureSubsetStrategy())
# print("Accuracy : " +  str(MulticlassClassificationEvaluator()\
#                            .evaluate(cvmodel.bestModel.transform(testing_set_5))))
